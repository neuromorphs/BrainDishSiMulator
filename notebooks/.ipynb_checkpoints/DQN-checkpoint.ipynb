# %%
import argparse
import os
import random
import time
from distutils.util import strtobool

import gymnasium as gym
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from stable_baselines3.common.atari_wrappers import (
    ClipRewardEnv,
    EpisodicLifeEnv,
    FireResetEnv,
    MaxAndSkipEnv,
    NoopResetEnv,
)
from stable_baselines3.common.buffers import ReplayBuffer
from torch.utils.tensorboard import SummaryWriter
from collections import defaultdict


def parse_args():
    args = {
        "exp-name": "AtariDQN",
        "seed": 1,
        "torch-deterministic": True,
        "cuda": True,
        "track": False,
        "wandb-project-name": "cleanRL",
        "wandb-entity": None,
        "capture-video": False,
        "save-model": False,
        "upload-model": False,
        "hf-entity": "",
        "env-id": "BreakoutNoFrameskip-v4",
        "total-timesteps": 10000000,
        "learning-rate": 1e-4,
        "num-envs": 1,
        "buffer-size": 1000000,
        "gamma": 0.99,
        "tau": 1.,
        "target-network-frequency": 1000,
        "batch-size": 32,
        "start-e": 1,
        "end-e": 0.01,
        "exploration-fraction": 0.20,
        "learning-starts": 80000,
        "train-frequency": 4
    }

    assert args["num-envs"] == 1, "vectorized envs are not supported at the moment"

    # Convert the dictionary to a defaultdict with default value as None
    args_dict = defaultdict(lambda: None, args)
    
    
    args_dict = dict(args_dict)

    class Args:
        def __init__(self, **kwargs):
            self.__dict__.update(kwargs)
            for k in list(self.__dict__.keys()):
                self.__dict__[k.replace("-","_")]=self.__dict__[k]
    args = Args(**args_dict)

    return args


def make_env(env_id, seed, idx, capture_video, run_name):
    def thunk():
        if capture_video and idx == 0:
            env = gym.make(env_id, render_mode="rgb_array")
            env = gym.wrappers.RecordVideo(env, f"videos/{run_name}")
        else:
            env = gym.make(env_id)
        env = gym.wrappers.RecordEpisodeStatistics(env)
        env = NoopResetEnv(env, noop_max=30)
        env = MaxAndSkipEnv(env, skip=4)
        env = EpisodicLifeEnv(env)
        if "FIRE" in env.unwrapped.get_action_meanings():
            env = FireResetEnv(env)
        env = ClipRewardEnv(env)
        env = gym.wrappers.ResizeObservation(env, (84, 84))
        env = gym.wrappers.GrayScaleObservation(env)
        env = gym.wrappers.FrameStack(env, 4)
        env.action_space.seed(seed)

        return env

    return thunk


# ALGO LOGIC: initialize agent here:
class QNetwork(nn.Module):
    def __init__(self, env):
        super().__init__()
        self.network = nn.Sequential(
            nn.Conv2d(4, 32, 8, stride=4),
            nn.ReLU(),
            nn.Conv2d(32, 64, 4, stride=2),
            nn.ReLU(),
            nn.Conv2d(64, 64, 3, stride=1),
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(3136, 512),
            nn.ReLU(),
            nn.Linear(512, env.single_action_space.n),
        )

    def forward(self, x):
        return self.network(x / 255.0)


def linear_schedule(start_e: float, end_e: float, duration: int, t: int):
    slope = (end_e - start_e) / duration
    return max(slope * t + start_e, end_e)

# %%
args = parse_args()
args.env_id
# Out:
# 'BreakoutNoFrameskip-v4'

# %%
import stable_baselines3 as sb3

if sb3.__version__ < "2.0":
    raise ValueError(
        """Ongoing migration: run the following command to install the new dependencies:

poetry run pip install "stable_baselines3==2.0.0a1" "gymnasium[atari,accept-rom-license]==0.28.1"  "ale-py==0.8.1" 
"""
    )
    
args = parse_args()
run_name = f"{args.env_id}__{args.exp_name}__{args.seed}__{int(time.time())}"
if args.track:
    import wandb

    wandb.init(
        project=args.wandb_project_name,
        entity=args.wandb_entity,
        sync_tensorboard=True,
        config=vars(args),
        name=run_name,
        monitor_gym=True,
        save_code=True,
    )
writer = SummaryWriter(f"runs/{run_name}")
writer.add_text(
    "hyperparameters",
    "|param|value|\n|-|-|\n%s" % ("\n".join([f"|{key}|{value}|" for key, value in vars(args).items()])),
)

# TRY NOT TO MODIFY: seeding
random.seed(args.seed)
np.random.seed(args.seed)
torch.manual_seed(args.seed)
torch.backends.cudnn.deterministic = args.torch_deterministic

device = torch.device("cuda" if torch.cuda.is_available() and args.cuda else "cpu")

# env setup
envs = gym.vector.SyncVectorEnv(
    [make_env(args.env_id, args.seed + i, i, args.capture_video, run_name) for i in range(args.num_envs)]
)
assert isinstance(envs.single_action_space, gym.spaces.Discrete), "only discrete action space is supported"

q_network = QNetwork(envs).to(device)
optimizer = optim.Adam(q_network.parameters(), lr=args.learning_rate)
target_network = QNetwork(envs).to(device)
target_network.load_state_dict(q_network.state_dict())

rb = ReplayBuffer(
    args.buffer_size,
    envs.single_observation_space,
    envs.single_action_space,
    device,
    optimize_memory_usage=True,
    handle_timeout_termination=False,
)
start_time = time.time()

# TRY NOT TO MODIFY: start the game
obs, _ = envs.reset(seed=args.seed)
for global_step in range(args.total_timesteps):
    # ALGO LOGIC: put action logic here
    epsilon = linear_schedule(args.start_e, args.end_e, args.exploration_fraction * args.total_timesteps, global_step)
    if random.random() < epsilon:
        actions = np.array([envs.single_action_space.sample() for _ in range(envs.num_envs)])
    else:
        q_values = q_network(torch.Tensor(obs).to(device))
        actions = torch.argmax(q_values, dim=1).cpu().numpy()

    # TRY NOT TO MODIFY: execute the game and log data.
    next_obs, rewards, terminated, truncated, infos = envs.step(actions)

    # TRY NOT TO MODIFY: record rewards for plotting purposes
    if "final_info" in infos:
        for info in infos["final_info"]:
            # Skip the envs that are not done
            if "episode" not in info:
                continue
            print(f"global_step={global_step}, episodic_return={info['episode']['r']}")
            writer.add_scalar("charts/episodic_return", info["episode"]["r"], global_step)
            writer.add_scalar("charts/episodic_length", info["episode"]["l"], global_step)
            writer.add_scalar("charts/epsilon", epsilon, global_step)

    # TRY NOT TO MODIFY: save data to reply buffer; handle `final_observation`
    real_next_obs = next_obs.copy()
    for idx, d in enumerate(truncated):
        if d:
            real_next_obs[idx] = infos["final_observation"][idx]
    rb.add(obs, real_next_obs, actions, rewards, terminated, infos)

    # TRY NOT TO MODIFY: CRUCIAL step easy to overlook
    obs = next_obs

    # ALGO LOGIC: training.
    if global_step > args.learning_starts:
        if global_step % args.train_frequency == 0:
            data = rb.sample(args.batch_size)
            with torch.no_grad():
                target_max, _ = target_network(data.next_observations).max(dim=1)
                td_target = data.rewards.flatten() + args.gamma * target_max * (1 - data.dones.flatten())
            old_val = q_network(data.observations).gather(1, data.actions).squeeze()
            loss = F.mse_loss(td_target, old_val)

            if global_step % 100 == 0:
                writer.add_scalar("losses/td_loss", loss, global_step)
                writer.add_scalar("losses/q_values", old_val.mean().item(), global_step)
                print("SPS:", int(global_step / (time.time() - start_time)))
                writer.add_scalar("charts/SPS", int(global_step / (time.time() - start_time)), global_step)

            # optimize the model
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        # update target network
        if global_step % args.target_network_frequency == 0:
            for target_network_param, q_network_param in zip(target_network.parameters(), q_network.parameters()):
                target_network_param.data.copy_(
                    args.tau * q_network_param.data + (1.0 - args.tau) * target_network_param.data
                )

if args.save_model:
    model_path = f"runs/{run_name}/{args.exp_name}.cleanrl_model"
    torch.save(q_network.state_dict(), model_path)
    print(f"model saved to {model_path}")
    from cleanrl_utils.evals.dqn_eval import evaluate

    episodic_returns = evaluate(
        model_path,
        make_env,
        args.env_id,
        eval_episodes=10,
        run_name=f"{run_name}-eval",
        Model=QNetwork,
        device=device,
        epsilon=0.05,
    )
    for idx, episodic_return in enumerate(episodic_returns):
        writer.add_scalar("eval/episodic_return", episodic_return, idx)

    if args.upload_model:
        from cleanrl_utils.huggingface import push_to_hub

        repo_name = f"{args.env_id}-{args.exp_name}-seed{args.seed}"
        repo_id = f"{args.hf_entity}/{repo_name}" if args.hf_entity else repo_name
        push_to_hub(args, episodic_returns, repo_id, "DQN", f"runs/{run_name}", f"videos/{run_name}-eval")

envs.close()
writer.close()
# Out:
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# /Users/sni/Documents/Projects/Telluride/BrainDishSiMulator/venv/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:229: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 28.24GB > 18.32GB
#   warnings.warn(
# global_step=139, episodic_return=[1.]
# global_step=324, episodic_return=[2.]
# global_step=435, episodic_return=[0.]
# global_step=673, episodic_return=[3.]
# global_step=935, episodic_return=[3.]
# global_step=1141, episodic_return=[2.]
# global_step=1352, episodic_return=[2.]
# global_step=1495, episodic_return=[1.]
# global_step=1608, episodic_return=[0.]
# global_step=1769, episodic_return=[1.]
# global_step=1884, episodic_return=[0.]
# global_step=1999, episodic_return=[0.]
# global_step=2158, episodic_return=[1.]
# global_step=2273, episodic_return=[0.]
# global_step=2483, episodic_return=[2.]
# global_step=2825, episodic_return=[6.]
# global_step=2940, episodic_return=[0.]
# global_step=3302, episodic_return=[6.]
# global_step=3445, episodic_return=[1.]
# global_step=3558, episodic_return=[0.]
# global_step=3696, episodic_return=[1.]
# global_step=3809, episodic_return=[0.]
# global_step=3922, episodic_return=[0.]
# global_step=4108, episodic_return=[2.]
# global_step=4390, episodic_return=[4.]
# global_step=4546, episodic_return=[1.]
# global_step=4659, episodic_return=[0.]
# global_step=4772, episodic_return=[0.]
# global_step=4885, episodic_return=[0.]
# global_step=5028, episodic_return=[1.]
# global_step=5171, episodic_return=[1.]
# SPS: 28
# SPS: 28
# SPS: 28
# global_step=108243, episodic_return=[5.]
# SPS: 28
# global_step=108354, episodic_return=[0.]
# SPS: 28
# SPS: 28
# global_step=108564, episodic_return=[2.]
# SPS: 28
# SPS: 28
# SPS: 28
# global_step=108828, episodic_return=[4.]
# SPS: 28
# global_step=108941, episodic_return=[0.]
# SPS: 28
# SPS: 28
# global_step=109132, episodic_return=[2.]
# SPS: 28
# SPS: 28
# global_step=109341, episodic_return=[2.]
# SPS: 28
# global_step=109454, episodic_return=[0.]
# SPS: 28
# SPS: 27
# global_step=109643, episodic_return=[2.]
# SPS: 27
# SPS: 27
# global_step=109850, episodic_return=[2.]
# SPS: 27
# global_step=109961, episodic_return=[0.]
# SPS: 27
# SPS: 27
# global_step=110104, episodic_return=[1.]
# SPS: 27
# global_step=110215, episodic_return=[0.]
# SPS: 27
# global_step=110388, episodic_return=[2.]
# SPS: 27
# SPS: 27
# global_step=110503, episodic_return=[0.]
# SPS: 9
# global_step=110618, episodic_return=[0.]
# SPS: 10
# SPS: 10
# SPS: 10
# global_step=110903, episodic_return=[4.]
# SPS: 10
# SPS: 8
# global_step=111157, episodic_return=[3.]
# SPS: 8
# global_step=111270, episodic_return=[0.]
# SPS: 8
# global_step=111385, episodic_return=[0.]
# SPS: 8
# SPS: 8
# global_step=111542, episodic_return=[1.]
# SPS: 8
# SPS: 8
# global_step=111734, episodic_return=[2.]
# SPS: 8
# global_step=111873, episodic_return=[1.]
# SPS: 2
# global_step=111984, episodic_return=[0.]
# SPS: 2
# global_step=112099, episodic_return=[0.]
# SPS: 2
# SPS: 2
# SPS: 2
# SPS: 2
# global_step=112412, episodic_return=[5.]
# SPS: 2
# global_step=112553, episodic_return=[1.]
# SPS: 2
# global_step=112694, episodic_return=[1.]
# SPS: 2
# SPS: 2
# global_step=112853, episodic_return=[1.]
# SPS: 2
# SPS: 2
# global_step=113037, episodic_return=[2.]
# SPS: 2
# global_step=113178, episodic_return=[1.]
# SPS: 2
# SPS: 2
# global_step=113366, episodic_return=[2.]
# SPS: 2
# SPS: 2
# SPS: 2
# global_step=113605, episodic_return=[3.]
# SPS: 2
# SPS: 2
# global_step=113861, episodic_return=[3.]
# SPS: 2
# SPS: 2
# global_step=114020, episodic_return=[1.]
# SPS: 2
# global_step=114159, episodic_return=[1.]
# SPS: 2
# SPS: 2
# global_step=114367, episodic_return=[2.]
# SPS: 2
# SPS: 2
# global_step=114579, episodic_return=[2.]
# SPS: 2
# global_step=114692, episodic_return=[0.]
# SPS: 2
# SPS: 2
# global_step=114803, episodic_return=[0.]
# SPS: 2
# global_step=114916, episodic_return=[0.]
# SPS: 2
# SPS: 2
# global_step=115150, episodic_return=[3.]
# SPS: 2
# global_step=115265, episodic_return=[0.]
# SPS: 2
# SPS: 2
# global_step=115406, episodic_return=[1.]
# SPS: 2
# global_step=115517, episodic_return=[0.]
# SPS: 2
# global_step=115632, episodic_return=[0.]
# SPS: 2
episodic_return=[3.]
# SPS: 1
# SPS: 1
# SPS: 1
# global_step=140336, episodic_return=[5.]
# SPS: 1
# SPS: 1
# global_step=140556, episodic_return=[3.]
# SPS: 1
# SPS: 1
# global_step=140701, episodic_return=[1.]
# SPS: 1
# SPS: 1
# global_step=140989, episodic_return=[4.]
# SPS: 1
# SPS: 1
# global_step=141102, episodic_return=[0.]
# SPS: 1
# SPS: 1
# global_step=141387, episodic_return=[4.]
# SPS: 1
# SPS: 1
# global_step=141571, episodic_return=[2.]
# SPS: 1
# SPS: 1
# global_step=141712, episodic_return=[1.]
# SPS: 1
# SPS: 1
# SPS: 1
# global_step=142015, episodic_return=[4.]
# SPS: 1
# SPS: 1
# global_step=142207, episodic_return=[2.]
# SPS: 1
# global_step=142370, episodic_return=[1.]
# SPS: 1
# global_step=142483, episodic_return=[0.]
# SPS: 1
# SPS: 1
# global_step=142624, episodic_return=[1.]
# SPS: 1
# global_step=142735, episodic_return=[0.]
# SPS: 1
# global_step=142850, episodic_return=[0.]
# SPS: 1
# SPS: 1
# global_step=143062, episodic_return=[2.]
# SPS: 1
# global_step=143175, episodic_return=[0.]
# SPS: 1
# SPS: 1
# SPS: 1
# global_step=143413, episodic_return=[3.]
# SPS: 1
# SPS: 1
# global_step=143605, episodic_return=[2.]
# SPS: 1
# SPS: 1
# SPS: 1
# global_step=143941, episodic_return=[5.]
# SPS: 1
# SPS: 1
# SPS: 1
# SPS: 1
# global_step=144396, episodic_return=[7.]
# SPS: 1
# SPS: 1
# global_step=144511, episodic_return=[0.]
# SPS: 1
# global_step=144670, episodic_return=[1.]
# SPS: 1
# global_step=144785, episodic_return=[0.]
# SPS: 1
# SPS: 1
# SPS: 1
# global_step=145100, episodic_return=[5.]
# SPS: 1
# SPS: 1
# SPS: 1
# SPS: 1
# global_step=145411, episodic_return=[5.]
# SPS: 1
# SPS: 1
# global_step=145645, episodic_return=[3.]
# SPS: 1
# SPS: 1
# SPS: 1
# global_step=145959, episodic_return=[7.]
# SPS: 1
# SPS: 1
# SPS: 1
# global_step=146275, episodic_return=[5.]
# SPS: 1
# global_step=146388, episodic_return=[0.]
# SPS: 1
# SPS: 1
# SPS: 1
# global_step=146675, episodic_return=[4.]
# SPS: 1
# SPS: 1
# SPS: 1
# global_step=146944, episodic_return=[4.]
# SPS: 1
# global_step=147059, episodic_return=[0.]
# SPS: 1
# SPS: 1
# global_step=147216, episodic_return=[1.]
# SPS: 1
# SPS: 1
# global_step=147498, episodic_return=[4.]
# SPS: 1
# SPS: 1
# SPS: 1
# global_step=147750, episodic_return=[3.]
# SPS: 1
# global_step=147865, episodic_return=[0.]
# SPS: 1
# SPS: 1
# SPS: 1
# global_step=148150, episodic_return=[4.]
# SPS: 1
# SPS: 1
# global_step=148366, episodic_return=[3.]
# SPS: 1
# SPS: 1
# global_step=148507, episodic_return=[1.]
# SPS: 1
# global_step=148666, episodic_return=[1.]
# SPS: 1
# global_step=148779, episodic_return=[0.]
# SPS: 1
# global_step=148892, episodic_return=[0.]
# SPS: 1
# SPS: 1
# global_step=149098, episodic_return=[2.]
# SPS: 1
# SPS: 1
# SPS: 1
# global_step=149336, episodic_return=[3.]
# SPS: 1
# global_step=149451, episodic_return=[0.]
# SPS: 1
# global_step=149595, episodic_return=[1.]
# SPS: 1
# SPS: 1
# global_step=149755, episodic_return=[1.]
# SPS: 1
# SPS: 1
# global_step=149969, episodic_return=[2.]
# SPS: 1
# SPS: 1
# global_step=150129, episodic_return=[1.]
# SPS: 1
# global_step=150272, episodic_return=[1.]
# SPS: 1
# SPS: 1
# SPS: 1
# SPS: 1
# global_step=150632, episodic_return=[8.]
# SPS: 1
# global_step=150796, episodic_return=[1.]
# SPS: 1
# SPS: 1
# global_step=150911, episodic_return=[0.]
# SPS: 1
# SPS: 1
# global_step=151120, episodic_return=[2.]
# SPS: 1
# SPS: 1
# SPS: 1
# global_step=151427, episodic_return=[4.]
# SPS: 1
# SPS: 1
# global_step=151616, episodic_return=[2.]
# SPS: 1
# SPS: 1
# global_step=151827, episodic_return=[2.]
# SPS: 1
# SPS: 1
# global_step=152050, episodic_return=[3.]
# SPS: 1
# global_step=152159, episodic_return=[0.]
# SPS: 1
# SPS: 1
# global_step=152330, episodic_return=[2.]
# SPS: 1
# SPS: 1
# global_step=152586, episodic_return=[3.]
# SPS: 1
# SPS: 1
# global_step=152701, episodic_return=[0.]
# SPS: 1
# global_step=152814, episodic_return=[0.]
# SPS: 1
# SPS: 1
# global_step=153094, episodic_return=[5.]
# SPS: 1
# SPS: 1
# global_step=153237, episodic_return=[1.]
# SPS: 1
# SPS: 1
# global_step=153475, episodic_return=[3.]
# SPS: 1
# SPS: 1
# SPS: 1
# global_step=153732, episodic_return=[3.]
# SPS: 1
# SPS: 1
# SPS: 1
# global_step=154035, episodic_return=[5.]
# SPS: 1
# global_step=154196, episodic_return=[1.]
# SPS: 1
# SPS: 1
# global_step=154354, episodic_return=[1.]
# SPS: 1
# global_step=154467, episodic_return=[0.]
# SPS: 1
# global_step=154582, episodic_return=[0.]
# SPS: 1
# SPS: 1
# SPS: 1
# global_step=154849, episodic_return=[4.]
# SPS: 1
# SPS: 1
# global_step=155034, episodic_return=[2.]
# SPS: 1
# SPS: 1
# SPS: 1
# global_step=155356, episodic_return=[8.]
# SPS: 1
# SPS: 1
# global_step=155566, episodic_return=[2.]
# SPS: 1
# SPS: 1
# global_step=155707, episodic_return=[1.]
# SPS: 1
# global_step=155879, episodic_return=[2.]
# SPS: 1
# SPS: 1
# global_step=156022, episodic_return=[1.]
# SPS: 1
# global_step=156179, episodic_return=[1.]
# SPS: 1
# SPS: 1
# global_step=156318, episodic_return=[1.]
# SPS: 1
# global_step=156480, episodic_return=[1.]
# SPS: 1
# SPS: 1
# global_step=156696, episodic_return=[3.]
# SPS: 1
# SPS: 1
# global_step=156837, episodic_return=[1.]
# SPS: 1
# global_step=156976, episodic_return=[1.]
# SPS: 1
# global_step=157087, episodic_return=[0.]
# SPS: 1
# SPS: 1
# global_step=157246, episodic_return=[1.]
# SPS: 1
# global_step=157359, episodic_return=[0.]
# SPS: 1
# global_step=157500, episodic_return=[1.]
# SPS: 1
# SPS: 1
# SPS: 1
# SPS: 1
# global_step=157836, episodic_return=[5.]
# SPS: 1
# SPS: 1
# SPS: 1
# global_step=158153, episodic_return=[5.]
# SPS: 1
# SPS: 1
# global_step=158363, episodic_return=[2.]
# SPS: 1
# SPS: 1
# global_step=158553, episodic_return=[2.]
# SPS: 1
# SPS: 1
# global_step=158740, episodic_return=[2.]
# SPS: 1
# SPS: 1
# SPS: 1
# global_step=159045, episodic_return=[4.]
# SPS: 1
# SPS: 1
# global_step=159283, episodic_return=[3.]
# SPS: 1
# SPS: 1
# SPS: 1
# global_step=159547, episodic_return=[4.]
# SPS: 1
# global_step=159662, episodic_return=[0.]
# SPS: 1
# global_step=159777, episodic_return=[0.]
# SPS: 1
# SPS: 1
# SPS: 1
# SPS: 1
# global_step=160189, episodic_return=[7.]
# SPS: 1
# SPS: 1
# SPS: 1
# global_step=160439, episodic_return=[4.]
# SPS: 1
# SPS: 1
# global_step=160625, episodic_return=[2.]
# SPS: 1
# global_step=160740, episodic_return=[0.]
# SPS: 1
# global_step=160900, episodic_return=[1.]
# SPS: 1
# SPS: 1
# global_step=161043, episodic_return=[1.]
# SPS: 1
# SPS: 1
# SPS: 1
# global_step