# %%
import sys
import os
import pathlib
import datetime
import numpy as np
import pandas as pd
import scipy.stats as sp
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as mpatches
import pingouin as pg
pd.options.display.max_columns = 150
# %matplotlib inline
sns.set()
pd.set_option('display.max_rows', 250)
sns.set_style("whitegrid")
from scipy.stats import ttest_ind
from statsmodels.stats.anova import AnovaRM
import warnings
warnings.filterwarnings('ignore')
path = "../models"
if not path in sys.path:
    sys.path.append(path)
# %reload_ext autoreload
# %autoreload 1
from statannot import add_stat_annotation
import patsy
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.stats.anova import AnovaRM
from statsmodels.regression.mixed_linear_model import MixedLMResults

import dishpill_models

# %%
def group_data(dataframe, tag_list):
    print("Chosen tags are", tag_list)
    df = dataframe
    mask = df['tag'].isin(tag_list)
    df = df[mask]
    group = df['tag'].str.contains('ctl', case = False)
    df['group'] = group.astype(int)
    halfmask = df['elapse_seconds']>t1
    df['elapse_minute_rounded'] = np.int32(df['elapse_seconds'] / 60.)
    df['20_sec'] = np.int32(df['elapse_seconds'] / 20.)
    df.loc[:,'half'] = halfmask
    df["half"] = df["half"].astype(int)
    
    #df = df[df['hit_count']>0]
    df
    return df

# %%
# use to this calculate probability and ln probability of hit_counts and shape data per 
# group to plot as heatmap
def hmShape(hmdf, groupNum):
    hmdfmask = ((hmdf['group'] == groupNum) & (hmdf['elapse_minute_rounded'] != 20))
    maskedhmdf = hmdf[hmdfmask]
    
    #This parts generates counts of the number of hits in a minute and works this out in log odds format (decibals).
    hmName = maskedhmdf.groupby(['elapse_minute_rounded', 'hit_count']).agg({'count':'sum'})                                                                      
    hmName = hmName.unstack(level=0)
    hchmnamecopy= hmName[['count']].copy()
    hchmname = hchmnamecopy.fillna(0)
    hchmname =hchmname.sort_values(by='hit_count', ascending=False)
    hchmname = hchmname.replace(0, 1)
    hchmname = hchmname.div(hchmname.sum(axis=0), axis=1)
    hchmname = ((1/hchmname)-1)
    hchmname[hchmname.columns[0:20]] = 10*np.log10(hchmname[hchmname.columns[0:20]])
    hchmname = hchmname.replace('inf', 0)
    hchmname = hchmname.fillna(0)
    
    #generates array cdf of hit counts
    cdfdfmask = ((hmdf['group'] == groupNum) & (hmdf['elapse_minute_rounded'] != 20))
    maskedcdfhmdf = hmdf[cdfdfmask]
    cdfhc = maskedcdfhmdf.groupby(['hit_count']).agg({'count':'sum'}) 
    cdfhc = cdfhc/cdfhc.sum()
    cdfhc = np.cumsum(cdfhc)
    cdfhc = cdfhc.reset_index()
    
    return hchmname, cdfhc

# %%
df = pd.read_pickle('Data/in_vitro_cells_sentience_2.pkl')

# %%
newdf = df
idlist = []
datelist = []
grouplist = []
for i, row in newdf.iterrows():
    if newdf.loc[i, 'group'] not in grouplist:
        idlist = []
        datelist = []
        grouplist.append(newdf.loc[i, 'group'])
        testday = 0
        newdf.loc[i, 'test_day'] = testday
    else:
        if newdf.loc[i, 'chip_id'] not in idlist:
            datelist = []
            testday = 0
            idlist.append(newdf.loc[i, 'chip_id'])
            newdf.loc[i, 'test_day'] = testday
            datelist.append(newdf.loc[i, 'date'])
        elif newdf.loc[i, 'chip_id']  in idlist:
            if newdf.loc[i, 'date'] in datelist:
                 newdf.loc[i, 'test_day'] = testday
            else:
                datelist.append(newdf.loc[i, 'date'])
                testday += 1
                newdf.loc[i, 'test_day'] = testday
            
        
    #print(datelist)

# %%
newdf['test_day']= np.where((newdf['test_day'] == 3) & ((newdf['tag'] == 'ngn2_rate_code_no_feedback') | (newdf['tag'] == 'ngn2_test_rate_code_no_feedback')), 2, newdf['test_day'])

# %%
hmdf = newdf[['group', 'session_num', 'elapse_minute_rounded', 'half', 'hit_count', 'count', 'ace', 'long_rally']].copy()
hmdf['hit_count'] = np.where(hmdf['hit_count'] > 4, 5, hmdf['hit_count'])
hmdf['group']= np.where((hmdf['session_num'] == 1), 3, df['group'])
hmdf
# Out:
#         group  session_num  elapse_minute_rounded  half  hit_count  count  \
# 338056      3          1.0                      0     0        2.0      1
# 338057      3          1.0                      0     0        0.0      1
# 338058      3          1.0                      0     0        1.0      1
# 338059      3          1.0                      1     0        2.0      1
# 338060      3          1.0                      1     0        0.0      1
# ...       ...          ...                    ...   ...        ...    ...
# 464111      4          3.0                     18     1        1.0      1
# 464112      4          3.0                     19     1        0.0      1
# 464113      4          3.0                     19     1        1.0      1
# 464114      4          3.0                     19     1        0.0      1
# 464115      4          3.0                     19     1        0.0      1
#
#         ace  long_rally
# 338056    0           0
# 338057    1           0
# 338058    0           0
# 338059    0           0
# 338060    1           0
# ...     ...         ...
# 464111    0           0
# 464112    1           0
# 464113    0           0
# 464114    1           0
# 464115    1           0
#
# [64728 rows x 8 columns]

# %%
hcstimhmdf, cdfstim = hmShape(hmdf, 0)
hcsilhmdf, cdfsil = hmShape(hmdf, 1)
hcNFhmdf, cdfNF = hmShape(hmdf, 2)
hcrsthmdf, cdfrst = hmShape(hmdf, 3)

# %%
hcrsthmdf
# Out:
#                            count                                              \
# elapse_minute_rounded         0          1          2          3          4
# hit_count
# 5.0                    19.406271  20.000000  20.048585  19.967305  18.540299
# 4.0                    18.140255  20.585345  16.232493  17.831337  19.939870
# 3.0                    13.233667  14.958218  15.579444  16.644207  14.229632
# 2.0                     6.732265  10.879908   9.643775   8.874705   8.897633
# 1.0                     4.002399   4.215446   5.427023   3.903869   4.269683
# 0.0                     0.547695  -1.765392  -2.113901  -0.847441  -0.929886
#
#                                                                               \
# elapse_minute_rounded         5          6          7          8          9
# hit_count
# 5.0                    20.264749  17.132104  16.205196  18.715729  18.523691
# 4.0                    17.213395  15.230675  16.699182  15.021895  17.459666
# 3.0                    14.629966  14.857214  14.313638  12.632414  14.534316
# 2.0                     8.550976   9.303413   9.042947   7.492751   8.266408
# 1.0                     4.254388   5.394872   6.135161   6.458603   4.785811
# 0.0                    -0.753660  -1.601144  -2.002997  -1.205739  -0.966639
#
#                                                                               \
# elapse_minute_rounded         10         11         12         13         14
# hit_count
# 5.0                    17.375334  19.305529  17.070021  15.241178  15.652573
# 4.0                    17.375334  18.842288  16.515060  18.530895  16.931405
# 3.0                    15.366732  13.129292  12.228347  12.098978  13.683769
# 2.0                     9.598464   9.275456  10.124093   8.930442   7.821912
# 1.0                     3.805272   3.835465   4.385728   4.085073   4.581534
# 0.0                    -0.748904  -0.537958  -0.816349  -0.084098  -0.218631
#
#
# elapse_minute_rounded         15         16         17         18         19
# hit_count
# 5.0                    18.004880  18.518141  18.887410  17.753584  15.127540
# 4.0                    17.651525  19.400736  17.098351  18.490283  17.662984
# 3.0                    12.612629  12.523906  14.002501  14.025480  13.501305
# 2.0                     8.837571   9.940096   8.657212   9.780283   9.250352
# 1.0                     3.842140   4.239627   5.609884   5.444224   5.491476
# 0.0                    -0.135375  -0.978959  -1.659588  -2.019718  -1.476715

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
sns.set(font_scale = 4)
fig, (ax1,ax2,ax3,ax4, axcb) = plt.subplots(1, 5, figsize=(40, 10), 
                                                gridspec_kw={'width_ratios':[1,1,1,1,0.08]})

fig.subplots_adjust(wspace=0.05)
sns.heatmap(hcstimhmdf, ax=ax1, cmap='rainbow_r',cbar_ax=axcb)
sns.heatmap(hcsilhmdf, ax=ax2, cmap='rainbow_r', cbar=False, yticklabels=False)
sns.heatmap(hcNFhmdf, ax=ax3, cmap='rainbow_r',cbar=False, yticklabels=False)
sns.heatmap(hcrsthmdf, ax=ax4, cmap='rainbow_r', cbar=False, yticklabels=False)
axcb.set_yticklabels([' ', '50%', '10%', '1%'], rotation = 90)
axcb.yaxis.set_major_locator(plt.MaxNLocator(3))
num = list(range(1,21, 2))
ax1.set_xticklabels(num, rotation=90)

ax2.set_xticklabels(num, rotation=90)
ax3.set_xticklabels(num, rotation=90)
ax4.set_xticklabels(num, rotation=90)
ax1.set_yticklabels(['   5+','4', '3', '2', '1', '0'], rotation = 90)
ax2.set(ylabel=None)
ax3.set(ylabel=None)
ax4.set(ylabel=None)

ax1.set(xlabel=None)
ax2.set(xlabel=None)
ax3.set_xlabel("Minute of Gameplay", size = 50, rotation = 180)
ax1.set_ylabel("Hits in Minute", size = 50)
ax4.set(xlabel=None)

ax4.set_title("Rest", size = 60)
ax1.set_title("Stimulus", size = 60)
ax2.set_title("Silent", size = 60)
ax3.set_title("No-feedback", size = 60)
plt.tight_layout()
plt.savefig('/home/jovyan/work/dishpill/Analysis/Plots/heatmap_feedback.pdf')
plt.show()

# %%
#normalises only by group
filtdf = df.groupby(['group', 'tag', 'chip_id', 'test_day', 'session_num', 'half', "control", 'elapse_minute_rounded']).mean()
data = filtdf.reset_index()
data = data.groupby(['group', 'tag', 'chip_id', 'test_day', 'half', 'session_num', "control"]).mean()
data = data[['hit_count']].copy()
data = data.unstack(level=6)
data=data.sort_values(by=["group", "tag", "chip_id", "test_day", "half",])
data[('hit_count', 1)] = data[('hit_count', 1)].fillna(method='ffill', inplace=False)
data = data.dropna()
data["normhc"] = ((data[('hit_count', 0)] - data[('hit_count', 1)]) / data[('hit_count', 1)] ) *100
data = data.reset_index()


data["id"] = ((data['group']).astype(str) + (data['chip_id']).astype(str)) + ((data['session_num']).astype(str))
data = data[(data.group != 4)]
data = data[(data.test_day != 3)]

data['session_num']= np.where((data['test_day'] == 1) & (data['session_num'] == 0), 3, data['session_num']) 
data['session_num']= np.where((data['test_day'] == 1)& (data['session_num'] == 1), 4, data['session_num']) 
data['session_num']= np.where((data['test_day'] == 1)& (data['session_num'] == 2), 5, data['session_num']) 
data['session_num']= np.where((data['test_day'] == 2)& (data['session_num'] == 0), 6, data['session_num']) 
data['session_num']= np.where((data['test_day'] == 2)& (data['session_num'] == 1), 7, data['session_num']) 
data['session_num']= np.where((data['test_day'] == 2)& (data['session_num'] == 2), 8, data['session_num']) 

data['test_day']= np.where((data['test_day'] == 4), 0, data['test_day']) 
data['test_day']= np.where((data['test_day'] == 5), 1, data['test_day']) 
data['test_day']= np.where((data['test_day'] == 6), 2, data['test_day']) 
data['test_day']= np.where((data['test_day'] == 7), 0, data['test_day']) 
data['test_day']= np.where((data['test_day'] == 8), 1, data['test_day']) 
data['test_day']= np.where((data['test_day'] == 9), 2, data['test_day']) 

data[:150]
#data.chip_id.unique()
# Out:
#         group                              tag chip_id test_day half  \
# control
# 0           0            GFP__rate_code_reseed   11597      1.0    0
# 1           0            GFP__rate_code_reseed   11597      1.0    0
# 2           0            GFP__rate_code_reseed   11597      1.0    0
# 3           0            GFP__rate_code_reseed   11597      1.0    1
# 4           0            GFP__rate_code_reseed   11597      1.0    1
# 5           0            GFP__rate_code_reseed   11597      1.0    1
# 6           0            GFP__rate_code_reseed   11597      2.0    0
# 7           0            GFP__rate_code_reseed   11597      2.0    0
# 8           0            GFP__rate_code_reseed   11597      2.0    0
# 9           0            GFP__rate_code_reseed   11597      2.0    1
# 10          0            GFP__rate_code_reseed   11597      2.0    1
# 11          0            GFP__rate_code_reseed   11597      2.0    1
# 12          0            GFP__rate_code_reseed   11609      0.0    0
# 13          0            GFP__rate_code_reseed   11609      0.0    0
# 14          0            GFP__rate_code_reseed   11609      0.0    0
# 15          0            GFP__rate_code_reseed   11609      0.0    1
# 16          0            GFP__rate_code_reseed   11609      0.0    1
# 17          0            GFP__rate_code_reseed   11609      0.0    1
# 18          0            GFP__rate_code_reseed   11609      1.0    0
# 19          0            GFP__rate_code_reseed   11609      1.0    0
# 20          0            GFP__rate_code_reseed   11609      1.0    0
# 21          0            GFP__rate_code_reseed   11609      1.0    1
# 22          0            GFP__rate_code_reseed   11609      1.0    1
# 23          0            GFP__rate_code_reseed   11609      1.0    1
# 24          0  GFP_low_test_rate_code_random_3   11597      0.0    0
# 25          0  GFP_low_test_rate_code_random_3   11597      0.0    0
# 26          0  GFP_low_test_rate_code_random_3   11597      0.0    0
# 27          0  GFP_low_test_rate_code_random_3   11597      0.0    1
# 28          0  GFP_low_test_rate_code_random_3   11597      0.0    1
# 29          0  GFP_low_test_rate_code_random_3   11597      0.0    1
# 30          0  GFP_low_test_rate_code_random_3   11613      0.0    0
# 31          0  GFP_low_test_rate_code_random_3   11613      0.0    0
# 32          0  GFP_low_test_rate_code_random_3   11613      0.0    0
# 33          0  GFP_low_test_rate_code_random_3   11613      0.0    1
# 34          0  GFP_low_test_rate_code_random_3   11613      0.0    1
# 35          0  GFP_low_test_rate_code_random_3   11613      0.0    1
# 36          0  GFP_low_test_rate_code_random_3   11615      0.0    0
# 37          0  GFP_low_test_rate_code_random_3   11615      0.0    0
# 38          0  GFP_low_test_rate_code_random_3   11615      0.0    0
# 39          0  GFP_low_test_rate_code_random_3   11615      0.0    1
# 40          0  GFP_low_test_rate_code_random_3   11615      0.0    1
# 41          0  GFP_low_test_rate_code_random_3   11615      0.0    1
# 42          0  GFP_low_test_rate_code_random_3   11615      1.0    0
# 43          0  GFP_low_test_rate_code_random_3   11615      1.0    0
# 44          0  GFP_low_test_rate_code_random_3   11615      1.0    0
# 45          0  GFP_low_test_rate_code_random_3   11615      1.0    1
# 46          0  GFP_low_test_rate_code_random_3   11615      1.0    1
# 47          0  GFP_low_test_rate_code_random_3   11615      1.0    1
# 48          0  GFP_low_test_rate_code_random_3   11618      0.0    0
# 49          0  GFP_low_test_rate_code_random_3   11618      0.0    0
# 50          0  GFP_low_test_rate_code_random_3   11618      0.0    0
# 51          0  GFP_low_test_rate_code_random_3   11618      0.0    1
# 52          0  GFP_low_test_rate_code_random_3   11618      0.0    1
# 53          0  GFP_low_test_rate_code_random_3   11618      0.0    1
# 54          0  GFP_low_test_rate_code_random_3   11623      0.0    0
# 55          0  GFP_low_test_rate_code_random_3   11623      0.0    0
# 56          0  GFP_low_test_rate_code_random_3   11623      0.0    0
# 57          0  GFP_low_test_rate_code_random_3   11623      0.0    1
# 58          0  GFP_low_test_rate_code_random_3   11623      0.0    1
# 59          0  GFP_low_test_rate_code_random_3   11623      0.0    1
# 60          0  GFP_low_test_rate_code_random_3    9353      0.0    0
# 61          0  GFP_low_test_rate_code_random_3    9353      0.0    0
# 62          0  GFP_low_test_rate_code_random_3    9353      0.0    0
# 63          0  GFP_low_test_rate_code_random_3    9353      0.0    1
# 64          0  GFP_low_test_rate_code_random_3    9353      0.0    1
# 65          0  GFP_low_test_rate_code_random_3    9353      0.0    1
# 66          0  GFP_low_test_rate_code_random_3    9353      1.0    0
# 67          0  GFP_low_test_rate_code_random_3    9353      1.0    0
# 68          0  GFP_low_test_rate_code_random_3    9353      1.0    0
# 69          0  GFP_low_test_rate_code_random_3    9353      1.0    1
# 70          0  GFP_low_test_rate_code_random_3    9353      1.0    1
# 71          0  GFP_low_test_rate_code_random_3    9353      1.0    1
# 72          0  GFP_low_test_rate_code_random_3    9353      2.0    0
# 73          0  GFP_low_test_rate_code_random_3    9353      2.0    0
# 74          0  GFP_low_test_rate_code_random_3    9353      2.0    0
# 75          0  GFP_low_test_rate_code_random_3    9353      2.0    1
# 76          0  GFP_low_test_rate_code_random_3    9353      2.0    1
# 77          0  GFP_low_test_rate_code_random_3    9353      2.0    1
# 84          0  GFP_low_test_rate_code_random_3    9353      0.0    0
# 85          0  GFP_low_test_rate_code_random_3    9353      0.0    0
# 86          0  GFP_low_test_rate_code_random_3    9353      0.0    0
# 87          0  GFP_low_test_rate_code_random_3    9353      0.0    1
# 88          0  GFP_low_test_rate_code_random_3    9353      0.0    1
# 89          0  GFP_low_test_rate_code_random_3    9353      0.0    1
# 90          0  GFP_low_test_rate_code_random_3    9353      1.0    0
# 91          0  GFP_low_test_rate_code_random_3    9353      1.0    0
# 92          0  GFP_low_test_rate_code_random_3    9353      1.0    0
# 93          0  GFP_low_test_rate_code_random_3    9353      1.0    1
# 94          0  GFP_low_test_rate_code_random_3    9353      1.0    1
# 95          0  GFP_low_test_rate_code_random_3    9353      1.0    1
# 96          0  GFP_low_test_rate_code_random_3    9358      0.0    0
# 97          0  GFP_low_test_rate_code_random_3    9358      0.0    0
# 98          0  GFP_low_test_rate_code_random_3    9358      0.0    0
# 99          0  GFP_low_test_rate_code_random_3    9358      0.0    1
# 100         0  GFP_low_test_rate_code_random_3    9358      0.0    1
# 101         0  GFP_low_test_rate_code_random_3    9358      0.0    1
# 102         0  GFP_low_test_rate_code_random_3    9358      1.0    0
# 103         0  GFP_low_test_rate_code_random_3    9358      1.0    0
# 104         0  GFP_low_test_rate_code_random_3    9358      1.0    0
# 105         0  GFP_low_test_rate_code_random_3    9358      1.0    1
# 106         0  GFP_low_test_rate_code_random_3    9358      1.0    1
# 107         0  GFP_low_test_rate_code_random_3    9358      1.0    1
# 108         0  GFP_low_test_rate_code_random_3    9358      2.0    0
# 109         0  GFP_low_test_rate_code_random_3    9358      2.0    0
# 110         0  GFP_low_test_rate_code_random_3    9358      2.0    0
# 111         0  GFP_low_test_rate_code_random_3    9358      2.0    1
# 112         0  GFP_low_test_rate_code_random_3    9358      2.0    1
# 113         0  GFP_low_test_rate_code_random_3    9358      2.0    1
# 120         0  GFP_low_test_rate_code_random_3    9358      0.0    0
# 121         0  GFP_low_test_rate_code_random_3    9358      0.0    0
# 122         0  GFP_low_test_rate_code_random_3    9358      0.0    0
# 123         0  GFP_low_test_rate_code_random_3    9358      0.0    1
# 124         0  GFP_low_test_rate_code_random_3    9358      0.0    1
# 125         0  GFP_low_test_rate_code_random_3    9358      0.0    1
# 126         0  GFP_low_test_rate_code_random_3    9358      1.0    0
# 127         0  GFP_low_test_rate_code_random_3    9358      1.0    0
# 128         0  GFP_low_test_rate_code_random_3    9358      1.0    0
# 129         0  GFP_low_test_rate_code_random_3    9358      1.0    1
# 130         0  GFP_low_test_rate_code_random_3    9358      1.0    1
# 131         0  GFP_low_test_rate_code_random_3    9358      1.0    1
# 132         0  GFP_low_test_rate_code_random_3    9358      2.0    0
# 133         0  GFP_low_test_rate_code_random_3    9358      2.0    0
# 134         0  GFP_low_test_rate_code_random_3    9358      2.0    0
# 135         0  GFP_low_test_rate_code_random_3    9358      2.0    1
# 136         0  GFP_low_test_rate_code_random_3    9358      2.0    1
# 137         0  GFP_low_test_rate_code_random_3    9358      2.0    1
# 138         0  GFP_low_test_rate_code_random_3    9358      0.0    0
# 139         0  GFP_low_test_rate_code_random_3    9358      0.0    0
# 140         0  GFP_low_test_rate_code_random_3    9358      0.0    0
# 141         0  GFP_low_test_rate_code_random_3    9358      0.0    1
# 142         0  GFP_low_test_rate_code_random_3    9358      0.0    1
# 143         0  GFP_low_test_rate_code_random_3    9358      0.0    1
# 144         0  GFP_low_test_rate_code_random_3    9358      1.0    0
# 145         0  GFP_low_test_rate_code_random_3    9358      1.0    0
# 146         0  GFP_low_test_rate_code_random_3    9358      1.0    0
# 147         0  GFP_low_test_rate_code_random_3    9358      1.0    1
# 148         0  GFP_low_test_rate_code_random_3    9358      1.0    1
# 149         0  GFP_low_test_rate_code_random_3    9358      1.0    1
# 150         0  GFP_low_test_rate_code_random_3    9468      0.0    0
# 151         0  GFP_low_test_rate_code_random_3    9468      0.0    0
# 152         0  GFP_low_test_rate_code_random_3    9468      0.0    0
# 153         0  GFP_low_test_rate_code_random_3    9468      0.0    1
# 154         0  GFP_low_test_rate_code_random_3    9468      0.0    1
# 155         0  GFP_low_test_rate_code_random_3    9468      0.0    1
# 156         0  GFP_low_test_rate_code_random_3    9468      1.0    0
# 157         0  GFP_low_test_rate_code_random_3    9468      1.0    0
# 158         0  GFP_low_test_rate_code_random_3    9468      1.0    0
# 159         0  GFP_low_test_rate_code_random_3    9468      1.0    1
# 160         0  GFP_low_test_rate_code_random_3    9468      1.0    1
# 161         0  GFP_low_test_rate_code_random_3    9468      1.0    1
#
#         session_num hit_count                normhc         id
# control                     0         1
# 0               4.0  0.340000  0.995675  -65.852298  0115971.0
# 1               5.0  0.800000  0.995675  -19.652465  0115972.0
# 2               3.0  0.650000  0.995675  -34.717628  0115973.0
# 3               4.0  0.696667  0.995675  -30.030688  0115971.0
# 4               5.0  0.533333  0.995675  -46.434977  0115972.0
# 5               3.0  0.772222  0.995675  -22.442310  0115973.0
# 6               7.0  0.636667  0.781825  -18.566643  0115971.0
# 7               8.0  0.473333  0.781825  -39.457923  0115972.0
# 8               3.0  0.540000  0.781825  -30.930870  0115973.0
# 9               7.0  1.061111  0.781825   35.722262  0115971.0
# 10              8.0  1.013333  0.781825   29.611207  0115972.0
# 11              3.0  1.127778  0.781825   44.249315  0115973.0
# 12              1.0  0.780000  0.660119   18.160505  0116091.0
# 13              2.0  0.790000  0.660119   19.675383  0116092.0
# 14              3.0  0.673333  0.660119    2.001803  0116093.0
# 15              1.0  1.150000  0.660119   74.211001  0116091.0
# 16              2.0  1.417778  0.660119  114.776075  0116092.0
# 17              3.0  0.865556  0.660119   31.121130  0116093.0
# 18              4.0  0.930000  0.693056   34.188377  0116091.0
# 19              5.0  0.800000  0.693056   15.430862  0116092.0
# 20              3.0  0.766667  0.693056   10.621242  0116093.0
# 21              4.0  0.655556  0.693056   -5.410822  0116091.0
# 22              5.0  1.188889  0.693056   71.543086  0116092.0
# 23              3.0  0.866667  0.693056   25.050100  0116093.0
# 24              1.0  0.600000  0.701389  -14.455446  0115971.0
# 25              2.0  0.400000  0.701389  -42.970297  0115972.0
# 26              3.0  1.016667  0.701389   44.950495  0115973.0
# 27              1.0  0.684444  0.701389   -2.415842  0115971.0
# 28              2.0  0.964444  0.701389   37.504950  0115972.0
# 29              3.0  0.817778  0.701389   16.594059  0115973.0
# 30              1.0  0.783333  0.634683   23.421283  0116131.0
# 31              2.0  0.700000  0.634683   10.291359  0116132.0
# 32              3.0  0.523333  0.634683  -17.544079  0116133.0
# 33              1.0  1.005556  0.634683   58.434413  0116131.0
# 34              2.0  0.788889  0.634683   24.296611  0116132.0
# 35              3.0  0.898889  0.634683   41.628111  0116133.0
# 36              1.0  0.290000  0.601905  -51.819620  0116151.0
# 37              2.0  0.640000  0.601905    6.329114  0116152.0
# 38              3.0  1.000000  0.601905   66.139241  0116153.0
# 39              1.0  1.194444  0.601905   98.444093  0116151.0
# 40              2.0  1.315556  0.601905  118.565401  0116152.0
# 41              3.0  1.322222  0.601905  119.672996  0116153.0
# 42              4.0  0.716667  0.715476    0.166389  0116151.0
# 43              5.0  0.983333  0.715476   37.437604  0116152.0
# 44              3.0  0.766667  0.715476    7.154742  0116153.0
# 45              4.0  0.822222  0.715476   14.919578  0116151.0
# 46              5.0  0.865556  0.715476   20.976151  0116152.0
# 47              3.0  0.755556  0.715476    5.601775  0116153.0
# 48              1.0  0.933333  0.786905   18.608169  0116181.0
# 49              2.0  0.693333  0.786905  -11.891074  0116182.0
# 50              3.0  0.406667  0.786905  -48.320726  0116183.0
# 51              1.0  0.782222  0.786905   -0.595058  0116181.0
# 52              2.0  0.796667  0.786905    1.240545  0116182.0
# 53              3.0  0.676667  0.786905  -14.009077  0116183.0
# 54              1.0  0.850000  0.789643    7.643600  0116231.0
# 55              2.0  0.456667  0.789643  -42.167948  0116232.0
# 56              3.0  1.316667  0.789643   66.742047  0116233.0
# 57              1.0  0.822222  0.789643    4.125835  0116231.0
# 58              2.0  0.867778  0.789643    9.894970  0116232.0
# 59              3.0  0.902222  0.789643   14.256998  0116233.0
# 60              1.0  0.716667  0.591587   21.143010   093531.0
# 61              2.0  0.616667  0.591587    4.239335   093532.0
# 62              3.0  0.570000  0.591587   -3.649047   093533.0
# 63              1.0  0.704444  0.591587   19.077006   093531.0
# 64              2.0  0.988889  0.591587   67.158573   093532.0
# 65              3.0  0.821111  0.591587   38.797961   093533.0
# 66              4.0  0.630000  0.711905  -11.505017   093531.0
# 67              5.0  0.340000  0.711905  -52.240803   093532.0
# 68              3.0  0.433333  0.711905  -39.130435   093533.0
# 69              4.0  1.083333  0.711905   52.173913   093531.0
# 70              5.0  0.955556  0.711905   34.225195   093532.0
# 71              3.0  1.006667  0.711905   41.404682   093533.0
# 72              7.0  0.600000  0.796032  -24.626122   093531.0
# 73              8.0  0.533333  0.796032  -33.000997   093532.0
# 74              3.0  0.433333  0.796032  -45.563310   093533.0
# 75              7.0  1.062222  0.796032   33.439681   093531.0
# 76              8.0  0.766667  0.796032   -3.688933   093532.0
# 77              3.0  0.980000  0.796032   23.110668   093533.0
# 84              1.0  0.783333  0.729921    7.317604   093531.0
# 85              2.0  0.783333  0.729921    7.317604   093532.0
# 86              3.0  1.083333  0.729921   48.417962   093533.0
# 87              1.0  1.184444  0.729921   62.270306   093531.0
# 88              2.0  0.713333  0.729921   -2.272480   093532.0
# 89              3.0  0.944444  0.729921   29.390018   093533.0
# 90              1.0  0.733333  0.698571    4.976142   093531.0
# 91              2.0  0.650000  0.698571   -6.952965   093532.0
# 92              3.0  0.816667  0.698571   16.905249   093533.0
# 93              1.0  0.700000  0.698571    0.204499   093531.0
# 94              2.0  0.913333  0.698571   30.743013   093532.0
# 95              3.0  0.866667  0.698571   24.062713   093533.0
# 96              1.0  0.716667  0.969127  -26.050283   093581.0
# 97              2.0  0.533333  0.969127  -44.967652   093582.0
# 98              3.0  0.630000  0.969127  -34.993039   093583.0
# 99              1.0  0.983333  0.969127    1.465891   093581.0
# 100             2.0  1.014444  0.969127    4.676112   093582.0
# 101             3.0  1.043333  0.969127    7.657031   093583.0
# 102             4.0  0.650000  0.485516   33.878218   093581.0
# 103             5.0  0.766667  0.485516   57.907642   093582.0
# 104             3.0  0.666667  0.485516   37.310993   093583.0
# 105             4.0  1.138889  0.485516  134.572946   093581.0
# 106             5.0  0.805556  0.485516   65.917450   093582.0
# 107             3.0  1.201111  0.485516  147.388639   093583.0
# 108             7.0  0.616667  0.783016  -21.244679   093581.0
# 109             8.0  0.666667  0.783016  -14.859112   093582.0
# 110             3.0  1.016667  0.783016   29.839854   093583.0
# 111             7.0  1.147778  0.783016   46.584229   093581.0
# 112             8.0  1.205556  0.783016   53.963106   093582.0
# 113             3.0  1.222222  0.783016   56.091628   093583.0
# 120             1.0  0.616667  0.721230  -14.497937   093581.0
# 121             2.0  0.600000  0.721230  -16.808803   093582.0
# 122             3.0  0.933333  0.721230   29.408528   093583.0
# 123             1.0  0.963333  0.721230   33.568088   093581.0
# 124             2.0  1.291111  0.721230   79.015131   093582.0
# 125             3.0  0.966667  0.721230   34.030261   093583.0
# 126             1.0  0.650000  0.660476   -1.586157   093581.0
# 127             2.0  0.683333  0.660476    3.460707   093582.0
# 128             3.0  0.533333  0.660476  -19.250180   093583.0
# 129             1.0  0.924444  0.660476   39.966354   093581.0
# 130             2.0  1.438889  0.660476  117.856285   093582.0
# 131             3.0  0.846667  0.660476   28.190339   093583.0
# 132             1.0  0.766667  0.662500   15.723270   093581.0
# 133             2.0  0.450000  0.662500  -32.075472   093582.0
# 134             3.0  0.416667  0.662500  -37.106918   093583.0
# 135             1.0  0.957778  0.662500   44.570231   093581.0
# 136             2.0  0.551111  0.662500  -16.813417   093582.0
# 137             3.0  0.913333  0.662500   37.861635   093583.0
# 138             1.0  0.700000  0.772222   -9.352518   093581.0
# 139             2.0  0.400000  0.772222  -48.201439   093582.0
# 140             3.0  0.650000  0.772222  -15.827338   093583.0
# 141             1.0  0.985556  0.772222   27.625899   093581.0
# 142             2.0  0.977778  0.772222   26.618705   093582.0
# 143             3.0  1.222222  0.772222   58.273381   093583.0
# 144             1.0  0.580000  0.813135  -28.671124   093581.0
# 145             2.0  0.750000  0.813135   -7.764384   093582.0
# 146             3.0  0.500000  0.813135  -38.509590   093583.0
# 147             1.0  0.691111  0.813135  -15.006588   093581.0
# 148             2.0  1.174444  0.813135   44.434142   093582.0
# 149             3.0  1.111111  0.813135   36.645356   093583.0
# 150             1.0  0.600000  0.593254    1.137124   094681.0
# 151             2.0  0.450000  0.593254  -24.147157   094682.0
# 152             3.0  0.340000  0.593254  -42.688963   094683.0
# 153             1.0  0.834444  0.593254   40.655518   094681.0
# 154             2.0  0.972222  0.593254   63.879599   094682.0
# 155             3.0  0.922222  0.593254   55.451505   094683.0
# 156             4.0  1.050000  0.824206   27.395282   094681.0
# 157             5.0  1.812500  0.824206  119.908522   094682.0
# 158             3.0  1.180000  0.824206   43.168031   094683.0
# 159             4.0  0.711111  0.824206  -13.721714   094681.0
# 160             5.0  0.765556  0.824206   -7.116033   094682.0
# 161             3.0  0.915556  0.824206   11.083293   094683.0

# %%
len(data)
# Out:
# 973

# %%
countprim= data.groupby(['chip_id']).mean()
countprim
# Out:
#             group  test_day      half session_num hit_count            \
# control                                                   0         1
# chip_id
# 11570    1.000000  1.000000  0.500000    4.000000  0.782741  0.963648
# 11597    1.000000  1.038462  0.500000    4.115385  0.823040  0.736588
# 11609    1.000000  1.000000  0.500000    4.000000  0.887441  0.815401
# 11610    1.000000  1.000000  0.500000    4.000000  0.853612  0.739789
# 11613    1.000000  1.000000  0.500000    4.000000  0.921506  0.844941
# 11614    0.000000  1.000000  0.500000    4.000000  0.862862  0.773955
# 11615    0.600000  0.800000  0.500000    3.600000  1.023111  0.764571
# 11618    1.000000  1.000000  0.500000    4.000000  0.765869  0.831010
# 11619    0.000000  1.000000  0.500000    4.000000  0.904938  0.612632
# 11621    0.000000  1.000000  0.500000    4.000000  0.879321  0.603505
# 11623    0.545455  0.454545  0.500000    2.909091  0.960860  0.818745
# 12106    1.219512  0.853659  0.487805    3.707317  1.141085  0.767322
# 12123    1.000000  1.000000  0.500000    4.000000  0.883572  0.777721
# 12138    1.000000  1.000000  0.500000    4.000000  1.172581  0.903237
# 12160    0.000000  0.000000  0.500000    2.000000  0.782222  0.627183
# 12250    1.000000  0.875000  0.500000    3.750000  1.032971  0.842767
# 12265    1.000000  1.000000  0.500000    4.000000  0.855508  0.874376
# 12285    1.000000  1.000000  0.500000    4.000000  1.071940  0.837115
# 13113    2.000000  0.500000  0.500000    3.000000  0.816938  0.793980
# 13117    2.000000  0.000000  0.500000    2.000000  0.953452  0.741374
# 13168    2.000000  0.500000  0.500000    3.000000  0.978313  0.792870
# 9353     0.166667  0.666667  0.500000    3.000000  0.804136  0.720741
# 9358     0.200000  0.800000  0.500000    2.800000  0.844204  0.749702
# 9381     0.000000  1.000000  0.500000    4.000000  0.781995  0.668902
# 9468     0.500000  0.500000  0.500000    3.000000  0.965810  0.731895
# 9495     0.272727  0.909091  0.500000    3.090909  0.850589  0.731064
# 9501     0.000000  1.000000  0.500000    4.000000  0.897798  0.593677
#
#             normhc
# control
# chip_id
# 11570    -8.373160
# 11597    16.293806
# 11609    11.636394
# 11610    18.713900
# 11613    10.305513
# 11614    15.604958
# 11615    36.699598
# 11618    -6.461187
# 11619    52.705647
# 11621    47.745336
# 11623    22.471035
# 12106    64.348119
# 12123    15.224125
# 12138    31.768770
# 12160    24.720025
# 12250    35.750697
# 12265     1.553236
# 12285    32.184489
# 13113     3.206383
# 13117    28.606191
# 13168    27.085288
# 9353     12.184801
# 9358     17.362459
# 9381     26.306939
# 9468     31.290769
# 9495     19.909305
# 9501     66.242776

# %%
aov = pg.mixed_anova(data=data, dv=('normhc'), subject=('id'), between='group', 
                     within= 'half',
                     correction = True, effsize='np2')
pg.print_table(aov)
# Out:
# =============
# ANOVA SUMMARY
# =============
#
# Source              SS    DF1    DF2         MS      F    p-unc    np2      eps
# -----------  ---------  -----  -----  ---------  -----  -------  -----  -------
# group        28245.063      2    165  14122.531  4.576    0.012  0.053  nan
# half         14603.331      1    165  14603.331  8.685    0.004  0.050    1.000
# Interaction  20768.205      2    165  10384.103  6.175    0.003  0.070  nan

# %%
Stimulus = data[(data.group == 0)]  
Silent = data[(data.group == 1)] 
Open = data[(data.group == 2)] 
Day0 = data[(data.test_day == 0)]  
Day1 = data[(data.test_day == 1)]  
Day2 = data[(data.test_day == 2)] 

Half0 = data[(data.half == 0)] 
Half1 = data[(data.half == 1)] 

Stimulusday0 = data[(data.group == 0)& (data.test_day == 0)] 
Stimulusday1 = data[(data.group == 0)& (data.test_day == 1)] 
Stimulusday2 = data[(data.group == 0)& (data.test_day == 2)] 


Silentday0 = data[(data.group == 1)& (data.test_day == 0)] 
Silentday1 = data[(data.group == 1)& (data.test_day == 1)] 
Silentday2 = data[(data.group == 1)& (data.test_day == 2)]

# %%
aov = pg.anova(data=Half0, dv=('normhc'), between='group', detailed = True)
pg.print_table(aov)
# Out:
# =============
# ANOVA SUMMARY
# =============
#
# Source             SS    DF        MS        F    p-unc      np2
# --------  -----------  ----  --------  -------  -------  -------
# group       15118.754     2  7559.377    2.181    0.114    0.009
# Within    1677238.577   484  3465.369  nan      nan      nan

# %%
aov = pg.anova(data=Half1, dv=('normhc'), between='group', detailed = True)
pg.print_table(aov)
# Out:
# =============
# ANOVA SUMMARY
# =============
#
# Source             SS    DF         MS        F    p-unc      np2
# --------  -----------  ----  ---------  -------  -------  -------
# group      107887.859     2  53943.929   20.507    0.000    0.078
# Within    1270526.294   483   2630.489  nan      nan      nan

# %%
pg.pairwise_gameshowell(data =Half1, dv='normhc', between='group').round(3)
# Out:
#    A  B  mean(A)  mean(B)    diff     se      T       df   pval  hedges
# 0  0  1   43.351   21.394  21.957  6.006  3.656  309.729  0.001   0.396
# 1  0  2   43.351    8.175  35.175  4.604  7.640  339.144  0.001   0.854
# 2  1  2   21.394    8.175  13.219  5.091  2.596  198.782  0.027   0.324

# %%
pg.pairwise_gameshowell(data =data, dv='normhc', between='group').round(3)
# Out:
#    A  B  mean(A)  mean(B)    diff     se      T       df   pval  hedges
# 0  0  1   26.470   21.751   4.719  4.687  1.007  587.819  0.568   0.077
# 1  0  2   26.470    8.875  17.596  3.664  4.802  702.976  0.001   0.380
# 2  1  2   21.751    8.875  12.876  4.231  3.043  430.201  0.007   0.269

# %%
Stimulus0 = data[(data.group == 0)& (data.half == 0)] 
Stimulus0 = Stimulus0[1:]
Stimulus1 = data[(data.group == 0)& (data.half == 1)] 
stats.ttest_rel(Stimulus0['normhc'], Stimulus1['normhc'])
# Out:
# Ttest_relResult(statistic=-7.479502683466953, pvalue=1.5814285717151388e-12)

# %%
countprim= Stimulus0.groupby(['group', 'chip_id']).mean()
countprim
# Out:
#               test_day half session_num hit_count                normhc
# control                                         0         1
# group chip_id
# 0     11570      1.000    0        4.00  0.657037  0.872870  -22.305148
#       11597      1.000    0        4.00  0.639583  0.805124  -19.475097
#       11609      1.000    0        4.00  0.819769  0.727513   13.127061
#       11610      1.000    0        4.00  0.735926  0.723624    3.401140
#       11613      1.000    0        4.00  0.609259  0.688651  -10.814677
#       11614      1.000    0        4.00  0.645556  0.773955  -14.047335
#       11615      0.500    0        3.00  0.732778  0.658690   10.901245
#       11618      1.000    0        4.00  0.662963  0.755992  -11.296027
#       11619      1.000    0        4.00  0.703704  0.612632   18.867913
#       11621      1.000    0        4.00  0.684815  0.603505   11.664062
#       11623      0.400    0        2.80  1.062762  0.962333   10.500268
#       12106      0.250    0        2.50  1.483333  0.462897  220.445778
#       12123      1.000    0        4.00  1.118889  0.725926   50.871296
#       12138      1.000    0        4.00  1.222037  0.881778   37.980738
#       12160      0.000    0        2.00  0.631111  0.627183    0.626384
#       12250      1.000    0        4.00  0.826296  0.847659   20.507496
#       12265      1.000    0        4.00  0.697536  0.897315  -17.828460
#       12285      1.000    0        4.00  0.957407  0.793218   20.079114
#       9353       0.800    0        3.20  0.648222  0.705603   -7.090119
#       9358       0.875    0        2.75  0.645556  0.733403   -8.509892
#       9381       1.000    0        4.00  0.746296  0.668902   23.425836
#       9468       0.500    0        3.00  0.905417  0.708730   20.795473
#       9495       0.875    0        2.75  0.722361  0.686085    6.901979
#       9501       1.000    0        4.00  0.760000  0.593677   39.979405

# %%
Silent0 = data[(data.group == 1)& (data.half == 0)] 
#Stimulus0 = Stimulus0[1:]
Silent1 = data[(data.group == 1)& (data.half == 1)] 
stats.ttest_rel(Silent0['normhc'], Silent1['normhc'])
# Out:
# Ttest_relResult(statistic=0.11386060188056854, pvalue=0.9095199954757324)

# %%
countprim= Silent0.groupby(['group', 'chip_id']).mean()
countprim
# Out:
#               test_day half session_num hit_count               normhc
# control                                         0         1
# group chip_id
# 1     11570      1.000    0       4.000  0.915185  0.871918  23.620077
#       11597      1.125    0       4.375  0.915565  0.657004  40.006027
#       11609      1.000    0       4.000  0.842593  0.951759  -9.574366
#       11613      1.000    0       4.000  0.894815  0.920238  -0.054265
#       11615      1.000    0       4.000  1.089259  0.835159  34.233414
#       11618      1.000    0       4.000  0.895926  0.861865   5.442937
#       11623      0.500    0       3.000  0.753333  0.699087   8.493642
#       12106      1.000    0       4.000  1.263280  0.836423  56.582074
#       12123      1.000    0       4.000  0.772619  0.827232  -5.892966
#       12138      1.000    0       4.000  1.598975  0.990577  67.695736
#       12250      0.500    0       3.000  0.764444  0.812679  -2.254526
#       12265      1.000    0       4.000  0.886340  0.842447   3.964049
#       12285      1.000    0       4.000  1.200979  0.946727  37.280364
#       9353       0.000    0       2.000  1.177778  0.796429  47.882412
#       9358       0.500    0       3.000  0.891667  0.814901  17.069140
#       9468       0.500    0       3.000  1.228194  0.755060  63.296935
#       9495       1.000    0       4.000  0.903333  0.851005   6.617566

# %%
Open0 = data[(data.group == 2)& (data.half == 0)] 
#Stimulus0 = Stimulus0[1:]
Open1 = data[(data.group == 2)& (data.half == 1)] 
stats.ttest_rel(Open0['normhc'], Open1['normhc'])
# Out:
# Ttest_relResult(statistic=0.4373862789513026, pvalue=0.6626109039986738)

# %%
countprim= Open0.groupby(['group', 'tag', 'chip_id']).mean()
countprim
# Out:
#                                   test_day half session_num hit_count  \
# control                                                             0
# group tag                 chip_id
# 2     gfp_test_open_loop  11570        1.0    0         4.0  0.758316
#                           11609        1.0    0         4.0  0.887725
#       ngn2_test_open_loop 12106        1.0    0         4.0  0.823785
#                           12123        1.0    0         4.0  0.720635
#                           12138        1.0    0         4.0  0.794259
#                           12250        1.0    0         4.0  0.943739
#                           12265        1.0    0         4.0  1.052557
#                           12285        1.0    0         4.0  1.209982
#       prim_test_open_loop 11597        1.0    0         4.0  0.892972
#                           11610        1.0    0         4.0  0.858333
#                           11613        1.0    0         4.0  0.987028
#                           11618        1.0    0         4.0  0.792769
#                           13113        0.5    0         3.0  0.816508
#                           13117        0.0    0         2.0  0.874577
#                           13168        0.5    0         3.0  0.979537
#
#                                                 normhc
# control                                   1
# group tag                 chip_id
# 2     gfp_test_open_loop  11570    1.146157 -33.547991
#                           11609    0.766931  16.806657
#       ngn2_test_open_loop 12106    0.822769   0.338793
#                           12123    0.780005  -7.294299
#                           12138    0.837356  -3.227240
#                           12250    0.857935  11.091841
#                           12265    0.883366  22.896346
#                           12285    0.771400  55.149785
#       prim_test_open_loop 11597    0.717620  28.570007
#                           11610    0.755955  13.281643
#                           11613    0.925935   6.770823
#                           11618    0.875173  -7.567970
#                           13113    0.793980   2.639098
#                           13117    0.741374  17.967067
#                           13168    0.792870  28.211194

# %%
aov = pg.mixed_anova(data=Half1, dv=('normhc'), subject=('id'), between='group', 
                     within= 'test_day',
                     correction = True, effsize='np2')
pg.print_table(aov)
# Out:
# =============
# ANOVA SUMMARY
# =============
#
# Source              SS    DF1    DF2         MS      F    p-unc    p-GG-corr    np2      eps    sphericity    W-spher    p-spher
# -----------  ---------  -----  -----  ---------  -----  -------  -----------  -----  -------  ------------  ---------  ---------
# group        98629.255      2    164  49314.628  7.674    0.001      nan      0.086  nan           nan        nan        nan
# test_day        32.230      2    328     16.115  0.037    0.963        0.963  0.000    0.995         1.000      0.995      0.739
# Interaction   3633.791      4    328    908.448  2.100    0.081      nan      0.025  nan           nan        nan        nan

# %%
pg.pairwise_gameshowell(data =Half1, dv='normhc', between='group').round(3)
# Out:
#    A  B  mean(A)  mean(B)    diff     se      T       df   pval  hedges
# 0  0  1   43.351   21.394  21.957  6.006  3.656  309.729  0.001   0.396
# 1  0  2   43.351    8.175  35.175  4.604  7.640  339.144  0.001   0.854
# 2  1  2   21.394    8.175  13.219  5.091  2.596  198.782  0.027   0.324

# %%
Stimulus = Half1[(data.group == 0)]  
Silent = Half1[(data.group == 1)] 
Open = Half1[(data.group == 2)] 
Day0 = Half1[(data.test_day == 0)]  
Day1 = Half1[(data.test_day == 1)]  
Day2 = Half1[(data.test_day == 2)]

# %%
aov = pg.rm_anova(dv='normhc', within='test_day',
                  subject='id', data=Stimulus, detailed=True,
                  effsize="ng2")
pg.print_table(aov)
# Out:
# =============
# ANOVA SUMMARY
# =============
#
# Source            SS    DF        MS        F    p-unc      ng2      eps
# --------  ----------  ----  --------  -------  -------  -------  -------
# test_day    1823.268     2   911.634   -3.704    1.000    0.002    0.989
# Error     -34951.605   142  -246.138  nan      nan      nan      nan

# %%
pg.pairwise_gameshowell(data =Stimulus, dv='normhc', between='test_day').round(3)
# Out:
#      A    B  mean(A)  mean(B)   diff     se      T       df   pval  hedges
# 0  0.0  1.0   45.647   44.381  1.265  9.751  0.130  163.407  0.900   0.020
# 1  0.0  2.0   45.647   38.871  6.776  9.410  0.720  144.708  0.733   0.119
# 2  1.0  2.0   44.381   38.871  5.510  9.690  0.569  140.628  0.819   0.095

# %%
aov = pg.rm_anova(dv='normhc', within='test_day',
                  subject='id', data=Silent, detailed=True,
                  effsize="ng2")
pg.print_table(aov)
# Out:
# =============
# ANOVA SUMMARY
# =============
#
# Source            SS    DF        MS        F    p-unc      ng2      eps
# --------  ----------  ----  --------  -------  -------  -------  -------
# test_day    1465.794     2   732.897    0.372    0.690    0.004    0.935
# Error     193169.170    98  1971.114  nan      nan      nan      nan

# %%
aov = pg.rm_anova(dv='normhc', within='test_day',
                  subject='id', data=Open, detailed=True,
                  effsize="ng2")
pg.print_table(aov)
# Out:
# =============
# ANOVA SUMMARY
# =============
#
# Source           SS    DF       MS        F    p-unc      ng2      eps
# --------  ---------  ----  -------  -------  -------  -------  -------
# test_day    376.958     2  188.479    0.943    0.393    0.005    0.979
# Error     17590.768    88  199.895  nan      nan      nan      nan

# %%
pg.pairwise_gameshowell(data =Half1, dv='normhc', between='group').round(3)
# Out:
#    A  B  mean(A)  mean(B)    diff     se      T       df   pval  hedges
# 0  0  1   43.351   21.394  21.957  6.006  3.656  309.729  0.001   0.396
# 1  0  2   43.351    8.175  35.175  4.604  7.640  339.144  0.001   0.854
# 2  1  2   21.394    8.175  13.219  5.091  2.596  198.782  0.027   0.324

# %%
aov = pg.rm_anova(dv='normhc', within='test_day',
                  subject='id', data=Stimulus, detailed=True,
                  effsize="ng2")
pg.print_table(aov)
# Out:
# =============
# ANOVA SUMMARY
# =============
#
# Source            SS    DF        MS        F    p-unc      ng2      eps
# --------  ----------  ----  --------  -------  -------  -------  -------
# test_day    1823.268     2   911.634   -3.704    1.000    0.002    0.989
# Error     -34951.605   142  -246.138  nan      nan      nan      nan

# %%
aov = pg.rm_anova(dv='normhc', within='test_day',
                  subject='id', data=Silent, detailed=True,
                  effsize="ng2")
pg.print_table(aov)
# Out:
# =============
# ANOVA SUMMARY
# =============
#
# Source            SS    DF        MS        F    p-unc      ng2      eps
# --------  ----------  ----  --------  -------  -------  -------  -------
# test_day    1465.794     2   732.897    0.372    0.690    0.004    0.935
# Error     193169.170    98  1971.114  nan      nan      nan      nan

# %%
aov = pg.rm_anova(dv='normhc', within='test_day',
                  subject='id', data=Open, detailed=True,
                  effsize="ng2")
pg.print_table(aov)
# Out:
# =============
# ANOVA SUMMARY
# =============
#
# Source           SS    DF       MS        F    p-unc      ng2      eps
# --------  ---------  ----  -------  -------  -------  -------  -------
# test_day    376.958     2  188.479    0.943    0.393    0.005    0.979
# Error     17590.768    88  199.895  nan      nan      nan      nan

# %%
aov = pg.anova(data=Day0, dv=('normhc'), between='group', detailed = True)
pg.print_table(aov)
# Out:
# =============
# ANOVA SUMMARY
# =============
#
# Source            SS    DF         MS        F    p-unc      np2
# --------  ----------  ----  ---------  -------  -------  -------
# group      51038.042     2  25519.021    8.663    0.000    0.088
# Within    527290.410   179   2945.756  nan      nan      nan

# %%
aov = pg.anova(data=Day1, dv=('normhc'), between='group', detailed = True)
pg.print_table(aov)
# Out:
# =============
# ANOVA SUMMARY
# =============
#
# Source            SS    DF         MS        F    p-unc      np2
# --------  ----------  ----  ---------  -------  -------  -------
# group      41566.621     2  20783.311    7.651    0.001    0.084
# Within    450919.816   166   2716.384  nan      nan      nan

# %%
aov = pg.anova(data=Day2, dv=('normhc'), between='group', detailed = True)
pg.print_table(aov)
# Out:
# =============
# ANOVA SUMMARY
# =============
#
# Source            SS    DF        MS        F    p-unc      np2
# --------  ----------  ----  --------  -------  -------  -------
# group      18708.182     2  9354.091    4.277    0.016    0.061
# Within    288665.404   132  2186.859  nan      nan      nan

# %%
pg.pairwise_gameshowell(data =Day0, dv='normhc', between='group').round(3)
# Out:
#    A  B  mean(A)  mean(B)    diff      se      T       df   pval  hedges
# 0  0  1   45.647   17.127  28.520  10.384  2.747  111.470  0.019   0.485
# 1  0  2   45.647    7.956  37.690   7.983  4.721  128.959  0.001   0.862
# 2  1  2   17.127    7.956   9.171   9.045  1.014   75.236  0.566   0.207

# %%
pg.pairwise_gameshowell(data =Day1, dv='normhc', between='group').round(3)
# Out:
#    A  B  mean(A)  mean(B)    diff     se      T       df   pval  hedges
# 0  0  1   44.381   23.583  20.798  9.928  2.095  118.966  0.095   0.380
# 1  0  2   44.381    6.239  38.142  8.071  4.726  113.187  0.001   0.902
# 2  1  2   23.583    6.239  17.344  7.955  2.180   72.380  0.082   0.460

# %%
pg.pairwise_gameshowell(data =Day2, dv='normhc', between='group').round(3)
# Out:
#    A  B  mean(A)  mean(B)    diff      se      T      df   pval  hedges
# 0  0  1   38.871   24.400  14.471  11.045  1.310  72.255  0.396   0.272
# 1  0  2   38.871   10.654  28.217   7.685  3.672  92.923  0.001   0.761
# 2  1  2   24.400   10.654  13.747   9.678  1.420  48.230  0.339   0.331

# %%
data.columns
# Out:
# MultiIndex([(      'group', ''),
#             (        'tag', ''),
#             (    'chip_id', ''),
#             (   'test_day', ''),
#             (       'half', ''),
#             ('session_num', ''),
#             (  'hit_count',  0),
#             (  'hit_count',  1),
#             (     'normhc', ''),
#             (         'id', '')],
#            names=[None, 'control'])

# %%
d = {'group': data[(      'group', '')], 'score': data[(     'normhc', '')], 
     'id': data[(         'id', '')], 'test_day': data[(   'test_day', '')], 
     'session_num': data[('session_num', '')], 'half': data[(       'half', '')]}
ad = pd.DataFrame(data=d)
ad.columns
ad['stim']= np.where((ad['group'] == 0), 1, 0) 
ad['sil']= np.where((ad['group'] == 1), 1, 0) 
ad['nf']= np.where((ad['group'] == 2), 1, 0)

# %%
labels = data.group.unique()
x_pos = np.arange(len(labels))
x = ad['group']
y = ad['score']
hue = ad['half']
sns.set(style="darkgrid")
ax = sns.boxplot(data=ad, x=x, y=y, hue=hue, palette="Set2", showfliers=False, showmeans = True, 
                 meanprops={"markerfacecolor":"black", 
                       "markeredgecolor":"black",
                      "markersize":"5"})
ax.set_xticks(x_pos)
ax.set_xticklabels(("Stimulus", "Silent", "No- \n feedback"))
#ax.set_title('Pong Performance By \n Condition & Time')
ax.set_ylabel('Δ Rally Length vs Rest (%)')
ax.set_xlabel('Group')
ax.grid(False)
ax.legend([0, 1], ["0-5", "6-20"])
L = plt.legend(loc='lower left', bbox_to_anchor=(-0.2, -0.5), title = "Minutes", borderaxespad=0.1, frameon=False)
L.get_texts()[0].set_text('0-5')
L.get_texts()[1].set_text('6-20')

y, h, col = 170, 5.6, 'k'
x00, x01 = -.2, .2
x10, x11 = .8, 1.2
x20, x21 = 1.8, 2.2
#Plot t-test between groups
plt.plot([x00, x00, x01, x01], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text(((x00 + x01)/2), y+ h, "****", ha='center', va='bottom', color=col, fontsize=8)
#Plot differences between groups time 2
plt.text(x11, y, "###", ha='center', va='bottom', color=col,  fontsize=8)

plt.text(x21, y, "###", ha='center', va='bottom', color=col, fontsize=8)
plt.text(x21, y-20, "%", ha='center', va='bottom', color=col, fontsize=8)


# Plot extra legend
#plt.text(4.4, 1.38, "#=p<0.01 \n vs Stimulus", ha='center', va='bottom', color=col)
#plt.text(4.4, 1.15, "#=p<0.05 \n vs Stimulus", ha='center', va='bottom', color=col)
#plt.text(4.4, .92, "%%=p<0.01  \n vs Silent", ha='center', va='bottom', color=col)
#plt.text(4.4, .69, "%=p<0.05  \n vs Silent", ha='center', va='bottom', color=col)

ax.set_ylim([-80, 200])
sns.set(rc={'figure.figsize':(3,3)})

#plt.savefig('/home/jovyan/work/dishpill/Analysis/Plots/feedback_normhc_sig.pdf', bbox_inches='tight')

# %%
labels = data.test_day.unique()
x_pos = np.arange(len(labels))
x = Half1['test_day']
y = Half1['normhc']
hue = Half1['group']
sns.set(style="darkgrid")
ax = sns.lineplot(data=data, x=x, y=y, hue=hue, palette="Set2", err_style = "band", ci= 68)
L = plt.legend(loc='lower left', bbox_to_anchor=(-0.2, -0.6), title = "Condition", borderaxespad=0.1, frameon=False, ncol = 2)
L.get_texts()[0].set_text('Stimulus')
L.get_texts()[1].set_text('Silent')
L.get_texts()[2].set_text('No-feedback')
ax.grid(False)
ax.set_xticks(x_pos)
ax.set_xticklabels(("1", "2", "3"))
#ax.set_title('Pong Performance By \n Condition & Time')
ax.set_ylabel('Aces vs Rest (%)')
ax.set_xlabel('Day of Testing')
#ax.set_ylim([0.6, 1])
ax.set_xlim([0, 2.4])

plt.text(2.2, 22, "###", ha='center', va='bottom', color=col,  fontsize=8)

plt.text(2.2, 9, "###", ha='center', va='bottom', color=col, fontsize=8)


#plt.savefig('/home/jovyan/work/dishpill/Analysis/Plots/feedback_normhc_days_sig.pdf', bbox_inches='tight')
# Out:
# Text(2.2, 9, '###')

# %%
#normalises only by group for aces
filtdf = df.groupby(['group', 'tag', 'chip_id', 'test_day', 'session_num', 'half', "control", 'elapse_minute_rounded']).mean()
data = filtdf.reset_index()
data = data.groupby(['group', 'tag', 'chip_id', 'test_day', 'half', 'session_num', "control"]).mean()
data = data[['ace']].copy()
data = data.unstack(level=6)
data=data.sort_values(by=["group", "tag", "chip_id", "test_day", "half",])
data[('ace', 1)] = data[('ace', 1)].fillna(method='ffill', inplace=False)
data = data.dropna()
data["normace"] = (data[('ace', 0)] - data[('ace', 1)]) *100#/ data[('ace', 1)] ) *100
data = data.reset_index()
data["id"] = ((data['group']).astype(str) + (data['chip_id']).astype(str)) + ((data['session_num']).astype(str))

data['test_day']= np.where((data['test_day'] == 4), 0, data['test_day']) 
data['test_day']= np.where((data['test_day'] == 5), 1, data['test_day']) 
data['test_day']= np.where((data['test_day'] == 6), 2, data['test_day']) 
data['test_day']= np.where((data['test_day'] == 7), 0, data['test_day']) 
data['test_day']= np.where((data['test_day'] == 8), 1, data['test_day']) 
data['test_day']= np.where((data['test_day'] == 9), 2, data['test_day']) 
data['session_num']= np.where((data['test_day'] == 1) & (data['session_num'] == 0), 3, data['session_num']) 
data['session_num']= np.where((data['test_day'] == 1)& (data['session_num'] == 1), 4, data['session_num']) 
data['session_num']= np.where((data['test_day'] == 1)& (data['session_num'] == 2), 5, data['session_num']) 
data['session_num']= np.where((data['test_day'] == 2)& (data['session_num'] == 0), 6, data['session_num']) 
data['session_num']= np.where((data['test_day'] == 2)& (data['session_num'] == 1), 7, data['session_num']) 
data['session_num']= np.where((data['test_day'] == 2)& (data['session_num'] == 2), 8, data['session_num']) 
data = data[(data.group != 4)]
data = data[(data.test_day != 3)]

data[:150]
#data.chip_id.unique()
# Out:
#         group                              tag chip_id test_day half  \
# control
# 0           0            GFP__rate_code_reseed   11597      1.0    0
# 1           0            GFP__rate_code_reseed   11597      1.0    0
# 2           0            GFP__rate_code_reseed   11597      1.0    0
# 3           0            GFP__rate_code_reseed   11597      1.0    1
# 4           0            GFP__rate_code_reseed   11597      1.0    1
# 5           0            GFP__rate_code_reseed   11597      1.0    1
# 6           0            GFP__rate_code_reseed   11597      2.0    0
# 7           0            GFP__rate_code_reseed   11597      2.0    0
# 8           0            GFP__rate_code_reseed   11597      2.0    0
# 9           0            GFP__rate_code_reseed   11597      2.0    1
# 10          0            GFP__rate_code_reseed   11597      2.0    1
# 11          0            GFP__rate_code_reseed   11597      2.0    1
# 12          0            GFP__rate_code_reseed   11609      0.0    0
# 13          0            GFP__rate_code_reseed   11609      0.0    0
# 14          0            GFP__rate_code_reseed   11609      0.0    0
# 15          0            GFP__rate_code_reseed   11609      0.0    1
# 16          0            GFP__rate_code_reseed   11609      0.0    1
# 17          0            GFP__rate_code_reseed   11609      0.0    1
# 18          0            GFP__rate_code_reseed   11609      1.0    0
# 19          0            GFP__rate_code_reseed   11609      1.0    0
# 20          0            GFP__rate_code_reseed   11609      1.0    0
# 21          0            GFP__rate_code_reseed   11609      1.0    1
# 22          0            GFP__rate_code_reseed   11609      1.0    1
# 23          0            GFP__rate_code_reseed   11609      1.0    1
# 24          0  GFP_low_test_rate_code_random_3   11597      0.0    0
# 25          0  GFP_low_test_rate_code_random_3   11597      0.0    0
# 26          0  GFP_low_test_rate_code_random_3   11597      0.0    0
# 27          0  GFP_low_test_rate_code_random_3   11597      0.0    1
# 28          0  GFP_low_test_rate_code_random_3   11597      0.0    1
# 29          0  GFP_low_test_rate_code_random_3   11597      0.0    1
# 30          0  GFP_low_test_rate_code_random_3   11613      0.0    0
# 31          0  GFP_low_test_rate_code_random_3   11613      0.0    0
# 32          0  GFP_low_test_rate_code_random_3   11613      0.0    0
# 33          0  GFP_low_test_rate_code_random_3   11613      0.0    1
# 34          0  GFP_low_test_rate_code_random_3   11613      0.0    1
# 35          0  GFP_low_test_rate_code_random_3   11613      0.0    1
# 36          0  GFP_low_test_rate_code_random_3   11615      0.0    0
# 37          0  GFP_low_test_rate_code_random_3   11615      0.0    0
# 38          0  GFP_low_test_rate_code_random_3   11615      0.0    0
# 39          0  GFP_low_test_rate_code_random_3   11615      0.0    1
# 40          0  GFP_low_test_rate_code_random_3   11615      0.0    1
# 41          0  GFP_low_test_rate_code_random_3   11615      0.0    1
# 42          0  GFP_low_test_rate_code_random_3   11615      1.0    0
# 43          0  GFP_low_test_rate_code_random_3   11615      1.0    0
# 44          0  GFP_low_test_rate_code_random_3   11615      1.0    0
# 45          0  GFP_low_test_rate_code_random_3   11615      1.0    1
# 46          0  GFP_low_test_rate_code_random_3   11615      1.0    1
# 47          0  GFP_low_test_rate_code_random_3   11615      1.0    1
# 48          0  GFP_low_test_rate_code_random_3   11618      0.0    0
# 49          0  GFP_low_test_rate_code_random_3   11618      0.0    0
# 50          0  GFP_low_test_rate_code_random_3   11618      0.0    0
# 51          0  GFP_low_test_rate_code_random_3   11618      0.0    1
# 52          0  GFP_low_test_rate_code_random_3   11618      0.0    1
# 53          0  GFP_low_test_rate_code_random_3   11618      0.0    1
# 54          0  GFP_low_test_rate_code_random_3   11623      0.0    0
# 55          0  GFP_low_test_rate_code_random_3   11623      0.0    0
# 56          0  GFP_low_test_rate_code_random_3   11623      0.0    0
# 57          0  GFP_low_test_rate_code_random_3   11623      0.0    1
# 58          0  GFP_low_test_rate_code_random_3   11623      0.0    1
# 59          0  GFP_low_test_rate_code_random_3   11623      0.0    1
# 60          0  GFP_low_test_rate_code_random_3    9353      0.0    0
# 61          0  GFP_low_test_rate_code_random_3    9353      0.0    0
# 62          0  GFP_low_test_rate_code_random_3    9353      0.0    0
# 63          0  GFP_low_test_rate_code_random_3    9353      0.0    1
# 64          0  GFP_low_test_rate_code_random_3    9353      0.0    1
# 65          0  GFP_low_test_rate_code_random_3    9353      0.0    1
# 66          0  GFP_low_test_rate_code_random_3    9353      1.0    0
# 67          0  GFP_low_test_rate_code_random_3    9353      1.0    0
# 68          0  GFP_low_test_rate_code_random_3    9353      1.0    0
# 69          0  GFP_low_test_rate_code_random_3    9353      1.0    1
# 70          0  GFP_low_test_rate_code_random_3    9353      1.0    1
# 71          0  GFP_low_test_rate_code_random_3    9353      1.0    1
# 72          0  GFP_low_test_rate_code_random_3    9353      2.0    0
# 73          0  GFP_low_test_rate_code_random_3    9353      2.0    0
# 74          0  GFP_low_test_rate_code_random_3    9353      2.0    0
# 75          0  GFP_low_test_rate_code_random_3    9353      2.0    1
# 76          0  GFP_low_test_rate_code_random_3    9353      2.0    1
# 77          0  GFP_low_test_rate_code_random_3    9353      2.0    1
# 84          0  GFP_low_test_rate_code_random_3    9353      0.0    0
# 85          0  GFP_low_test_rate_code_random_3    9353      0.0    0
# 86          0  GFP_low_test_rate_code_random_3    9353      0.0    0
# 87          0  GFP_low_test_rate_code_random_3    9353      0.0    1
# 88          0  GFP_low_test_rate_code_random_3    9353      0.0    1
# 89          0  GFP_low_test_rate_code_random_3    9353      0.0    1
# 90          0  GFP_low_test_rate_code_random_3    9353      1.0    0
# 91          0  GFP_low_test_rate_code_random_3    9353      1.0    0
# 92          0  GFP_low_test_rate_code_random_3    9353      1.0    0
# 93          0  GFP_low_test_rate_code_random_3    9353      1.0    1
# 94          0  GFP_low_test_rate_code_random_3    9353      1.0    1
# 95          0  GFP_low_test_rate_code_random_3    9353      1.0    1
# 96          0  GFP_low_test_rate_code_random_3    9358      0.0    0
# 97          0  GFP_low_test_rate_code_random_3    9358      0.0    0
# 98          0  GFP_low_test_rate_code_random_3    9358      0.0    0
# 99          0  GFP_low_test_rate_code_random_3    9358      0.0    1
# 100         0  GFP_low_test_rate_code_random_3    9358      0.0    1
# 101         0  GFP_low_test_rate_code_random_3    9358      0.0    1
# 102         0  GFP_low_test_rate_code_random_3    9358      1.0    0
# 103         0  GFP_low_test_rate_code_random_3    9358      1.0    0
# 104         0  GFP_low_test_rate_code_random_3    9358      1.0    0
# 105         0  GFP_low_test_rate_code_random_3    9358      1.0    1
# 106         0  GFP_low_test_rate_code_random_3    9358      1.0    1
# 107         0  GFP_low_test_rate_code_random_3    9358      1.0    1
# 108         0  GFP_low_test_rate_code_random_3    9358      2.0    0
# 109         0  GFP_low_test_rate_code_random_3    9358      2.0    0
# 110         0  GFP_low_test_rate_code_random_3    9358      2.0    0
# 111         0  GFP_low_test_rate_code_random_3    9358      2.0    1
# 112         0  GFP_low_test_rate_code_random_3    9358      2.0    1
# 113         0  GFP_low_test_rate_code_random_3    9358      2.0    1
# 120         0  GFP_low_test_rate_code_random_3    9358      0.0    0
# 121         0  GFP_low_test_rate_code_random_3    9358      0.0    0
# 122         0  GFP_low_test_rate_code_random_3    9358      0.0    0
# 123         0  GFP_low_test_rate_code_random_3    9358      0.0    1
# 124         0  GFP_low_test_rate_code_random_3    9358      0.0    1
# 125         0  GFP_low_test_rate_code_random_3    9358      0.0    1
# 126         0  GFP_low_test_rate_code_random_3    9358      1.0    0
# 127         0  GFP_low_test_rate_code_random_3    9358      1.0    0
# 128         0  GFP_low_test_rate_code_random_3    9358      1.0    0
# 129         0  GFP_low_test_rate_code_random_3    9358      1.0    1
# 130         0  GFP_low_test_rate_code_random_3    9358      1.0    1
# 131         0  GFP_low_test_rate_code_random_3    9358      1.0    1
# 132         0  GFP_low_test_rate_code_random_3    9358      2.0    0
# 133         0  GFP_low_test_rate_code_random_3    9358      2.0    0
# 134         0  GFP_low_test_rate_code_random_3    9358      2.0    0
# 135         0  GFP_low_test_rate_code_random_3    9358      2.0    1
# 136         0  GFP_low_test_rate_code_random_3    9358      2.0    1
# 137         0  GFP_low_test_rate_code_random_3    9358      2.0    1
# 138         0  GFP_low_test_rate_code_random_3    9358      0.0    0
# 139         0  GFP_low_test_rate_code_random_3    9358      0.0    0
# 140         0  GFP_low_test_rate_code_random_3    9358      0.0    0
# 141         0  GFP_low_test_rate_code_random_3    9358      0.0    1
# 142         0  GFP_low_test_rate_code_random_3    9358      0.0    1
# 143         0  GFP_low_test_rate_code_random_3    9358      0.0    1
# 144         0  GFP_low_test_rate_code_random_3    9358      1.0    0
# 145         0  GFP_low_test_rate_code_random_3    9358      1.0    0
# 146         0  GFP_low_test_rate_code_random_3    9358      1.0    0
# 147         0  GFP_low_test_rate_code_random_3    9358      1.0    1
# 148         0  GFP_low_test_rate_code_random_3    9358      1.0    1
# 149         0  GFP_low_test_rate_code_random_3    9358      1.0    1
# 150         0  GFP_low_test_rate_code_random_3    9468      0.0    0
# 151         0  GFP_low_test_rate_code_random_3    9468      0.0    0
# 152         0  GFP_low_test_rate_code_random_3    9468      0.0    0
# 153         0  GFP_low_test_rate_code_random_3    9468      0.0    1
# 154         0  GFP_low_test_rate_code_random_3    9468      0.0    1
# 155         0  GFP_low_test_rate_code_random_3    9468      0.0    1
# 156         0  GFP_low_test_rate_code_random_3    9468      1.0    0
# 157         0  GFP_low_test_rate_code_random_3    9468      1.0    0
# 158         0  GFP_low_test_rate_code_random_3    9468      1.0    0
# 159         0  GFP_low_test_rate_code_random_3    9468      1.0    1
# 160         0  GFP_low_test_rate_code_random_3    9468      1.0    1
# 161         0  GFP_low_test_rate_code_random_3    9468      1.0    1
#
#         session_num       ace              normace         id
# control                     0         1
# 0               4.0  0.760000  0.540198  21.980159  0115971.0
# 1               5.0  0.450000  0.540198  -9.019841  0115972.0
# 2               3.0  0.633333  0.540198   9.313492  0115973.0
# 3               4.0  0.558889  0.540198   1.869048  0115971.0
# 4               5.0  0.627778  0.540198   8.757937  0115972.0
# 5               3.0  0.544444  0.540198   0.424603  0115973.0
# 6               7.0  0.520000  0.625873 -10.587302  0115971.0
# 7               8.0  0.643333  0.625873   1.746032  0115972.0
# 8               3.0  0.643333  0.625873   1.746032  0115973.0
# 9               7.0  0.483333  0.625873 -14.253968  0115971.0
# 10              8.0  0.520000  0.625873 -10.587302  0115972.0
# 11              3.0  0.488889  0.625873 -13.698413  0115973.0
# 12              1.0  0.420000  0.595635 -17.563492  0116091.0
# 13              2.0  0.593333  0.595635  -0.230159  0116092.0
# 14              3.0  0.526667  0.595635  -6.896825  0116093.0
# 15              1.0  0.394444  0.595635 -20.119048  0116091.0
# 16              2.0  0.328889  0.595635 -26.674603  0116092.0
# 17              3.0  0.467778  0.595635 -12.785714  0116093.0
# 18              4.0  0.436667  0.638492 -20.182540  0116091.0
# 19              5.0  0.383333  0.638492 -25.515873  0116092.0
# 20              3.0  0.483333  0.638492 -15.515873  0116093.0
# 21              4.0  0.622222  0.638492  -1.626984  0116091.0
# 22              5.0  0.416667  0.638492 -22.182540  0116092.0
# 23              3.0  0.488889  0.638492 -14.960317  0116093.0
# 24              1.0  0.583333  0.615278  -3.194444  0115971.0
# 25              2.0  0.650000  0.615278   3.472222  0115972.0
# 26              3.0  0.466667  0.615278 -14.861111  0115973.0
# 27              1.0  0.540000  0.615278  -7.527778  0115971.0
# 28              2.0  0.467778  0.615278 -14.750000  0115972.0
# 29              3.0  0.562222  0.615278  -5.305556  0115973.0
# 30              1.0  0.466667  0.647460 -18.079365  0116131.0
# 31              2.0  0.500000  0.647460 -14.746032  0116132.0
# 32              3.0  0.626667  0.647460  -2.079365  0116133.0
# 33              1.0  0.544444  0.647460 -10.301587  0116131.0
# 34              2.0  0.494444  0.647460 -15.301587  0116132.0
# 35              3.0  0.540000  0.647460 -10.746032  0116133.0
# 36              1.0  0.760000  0.694167   6.583333  0116151.0
# 37              2.0  0.476667  0.694167 -21.750000  0116152.0
# 38              3.0  0.366667  0.694167 -32.750000  0116153.0
# 39              1.0  0.416667  0.694167 -27.750000  0116151.0
# 40              2.0  0.392222  0.694167 -30.194444  0116152.0
# 41              3.0  0.361111  0.694167 -33.305556  0116153.0
# 42              4.0  0.600000  0.571429   2.857143  0116151.0
# 43              5.0  0.566667  0.571429  -0.476190  0116152.0
# 44              3.0  0.433333  0.571429 -13.809524  0116153.0
# 45              4.0  0.472222  0.571429  -9.920635  0116151.0
# 46              5.0  0.520000  0.571429  -5.142857  0116152.0
# 47              3.0  0.511111  0.571429  -6.031746  0116153.0
# 48              1.0  0.450000  0.479762  -2.976190  0116181.0
# 49              2.0  0.440000  0.479762  -3.976190  0116182.0
# 50              3.0  0.693333  0.479762  21.357143  0116183.0
# 51              1.0  0.556667  0.479762   7.690476  0116181.0
# 52              2.0  0.603333  0.479762  12.357143  0116182.0
# 53              3.0  0.586667  0.479762  10.690476  0116183.0
# 54              1.0  0.516667  0.571548  -5.488095  0116231.0
# 55              2.0  0.660000  0.571548   8.845238  0116232.0
# 56              3.0  0.300000  0.571548 -27.154762  0116233.0
# 57              1.0  0.527778  0.571548  -4.376984  0116231.0
# 58              2.0  0.515556  0.571548  -5.599206  0116232.0
# 59              3.0  0.531111  0.571548  -4.043651  0116233.0
# 60              1.0  0.533333  0.640397 -10.706349   093531.0
# 61              2.0  0.566667  0.640397  -7.373016   093532.0
# 62              3.0  0.563333  0.640397  -7.706349   093533.0
# 63              1.0  0.564444  0.640397  -7.595238   093531.0
# 64              2.0  0.405556  0.640397 -23.484127   093532.0
# 65              3.0  0.564444  0.640397  -7.595238   093533.0
# 66              4.0  0.520000  0.540476  -2.047619   093531.0
# 67              5.0  0.726667  0.540476  18.619048   093532.0
# 68              3.0  0.683333  0.540476  14.285714   093533.0
# 69              4.0  0.444444  0.540476  -9.603175   093531.0
# 70              5.0  0.532222  0.540476  -0.825397   093532.0
# 71              3.0  0.451111  0.540476  -8.936508   093533.0
# 72              7.0  0.533333  0.615913  -8.257937   093531.0
# 73              8.0  0.583333  0.615913  -3.257937   093532.0
# 74              3.0  0.666667  0.615913   5.075397   093533.0
# 75              7.0  0.440000  0.615913 -17.591270   093531.0
# 76              8.0  0.522222  0.615913  -9.369048   093532.0
# 77              3.0  0.514444  0.615913 -10.146825   093533.0
# 84              1.0  0.533333  0.636429 -10.309524   093531.0
# 85              2.0  0.350000  0.636429 -28.642857   093532.0
# 86              3.0  0.366667  0.636429 -26.976190   093533.0
# 87              1.0  0.503333  0.636429 -13.309524   093531.0
# 88              2.0  0.614444  0.636429  -2.198413   093532.0
# 89              3.0  0.483333  0.636429 -15.309524   093533.0
# 90              4.0  0.383333  0.583571 -20.023810   093531.0
# 91              5.0  0.633333  0.583571   4.976190   093532.0
# 92              3.0  0.466667  0.583571 -11.690476   093533.0
# 93              4.0  0.627778  0.583571   4.420635   093531.0
# 94              5.0  0.547778  0.583571  -3.579365   093532.0
# 95              3.0  0.522222  0.583571  -6.134921   093533.0
# 96              1.0  0.500000  0.465397   3.460317   093581.0
# 97              2.0  0.583333  0.465397  11.793651   093582.0
# 98              3.0  0.503333  0.465397   3.793651   093583.0
# 99              1.0  0.438889  0.465397  -2.650794   093581.0
# 100             2.0  0.545556  0.465397   8.015873   093582.0
# 101             3.0  0.506667  0.465397   4.126984   093583.0
# 102             4.0  0.516667  0.653770 -13.710317   093581.0
# 103             5.0  0.450000  0.653770 -20.376984   093582.0
# 104             3.0  0.516667  0.653770 -13.710317   093583.0
# 105             4.0  0.466667  0.653770 -18.710317   093581.0
# 106             5.0  0.561111  0.653770  -9.265873   093582.0
# 107             3.0  0.486667  0.653770 -16.710317   093583.0
# 108             7.0  0.500000  0.564008  -6.400794   093581.0
# 109             8.0  0.516667  0.564008  -4.734127   093582.0
# 110             3.0  0.466667  0.564008  -9.734127   093583.0
# 111             7.0  0.536667  0.564008  -2.734127   093581.0
# 112             8.0  0.533333  0.564008  -3.067460   093582.0
# 113             3.0  0.550000  0.564008  -1.400794   093583.0
# 120             1.0  0.566667  0.587103  -2.043651   093581.0
# 121             2.0  0.583333  0.587103  -0.376984   093582.0
# 122             3.0  0.400000  0.587103 -18.710317   093583.0
# 123             1.0  0.522222  0.587103  -6.488095   093581.0
# 124             2.0  0.481111  0.587103 -10.599206   093582.0
# 125             3.0  0.555556  0.587103  -3.154762   093583.0
# 126             4.0  0.583333  0.574048   0.928571   093581.0
# 127             5.0  0.550000  0.574048  -2.404762   093582.0
# 128             3.0  0.583333  0.574048   0.928571   093583.0
# 129             4.0  0.447778  0.574048 -12.626984   093581.0
# 130             5.0  0.344444  0.574048 -22.960317   093582.0
# 131             3.0  0.542222  0.574048  -3.182540   093583.0
# 132             7.0  0.533333  0.614286  -8.095238   093581.0
# 133             8.0  0.600000  0.614286  -1.428571   093582.0
# 134             3.0  0.683333  0.614286   6.904762   093583.0
# 135             7.0  0.520000  0.614286  -9.428571   093581.0
# 136             8.0  0.656667  0.614286   4.238095   093582.0
# 137             3.0  0.436667  0.614286 -17.761905   093583.0
# 138             1.0  0.550000  0.497222   5.277778   093581.0
# 139             2.0  0.650000  0.497222  15.277778   093582.0
# 140             3.0  0.516667  0.497222   1.944444   093583.0
# 141             1.0  0.497778  0.497222   0.055556   093581.0
# 142             2.0  0.483333  0.497222  -1.388889   093582.0
# 143             3.0  0.483333  0.497222  -1.388889   093583.0
# 144             4.0  0.520000  0.664127 -14.412698   093581.0
# 145             5.0  0.550000  0.664127 -11.412698   093582.0
# 146             3.0  0.550000  0.664127 -11.412698   093583.0
# 147             4.0  0.592222  0.664127  -7.190476   093581.0
# 148             5.0  0.520000  0.664127 -14.412698   093582.0
# 149             3.0  0.422222  0.664127 -24.190476   093583.0
# 150             1.0  0.633333  0.678571  -4.523810   094681.0
# 151             2.0  0.650000  0.678571  -2.857143   094682.0
# 152             3.0  0.760000  0.678571   8.142857   094683.0
# 153             1.0  0.460000  0.678571 -21.857143   094681.0
# 154             2.0  0.483333  0.678571 -19.523810   094682.0
# 155             3.0  0.494444  0.678571 -18.412698   094683.0
# 156             4.0  0.450000  0.606151 -15.615079   094681.0
# 157             5.0  0.312500  0.606151 -29.365079   094682.0
# 158             3.0  0.453333  0.606151 -15.281746   094683.0
# 159             4.0  0.544444  0.606151  -6.170635   094681.0
# 160             5.0  0.601111  0.606151  -0.503968   094682.0
# 161             3.0  0.523333  0.606151  -8.281746   094683.0

# %%
aov = pg.mixed_anova(data=data, dv=('normace'), subject=('id'), between='group', 
                     within= 'half',
                     correction = True, effsize='np2')
pg.print_table(aov)
# Out:
# =============
# ANOVA SUMMARY
# =============
#
# Source             SS    DF1    DF2       MS      F    p-unc    np2      eps
# -----------  --------  -----  -----  -------  -----  -------  -----  -------
# group        1972.221      2    165  986.111  7.931    0.001  0.088  nan
# half            9.920      1    165    9.920  0.272    0.602  0.002    1.000
# Interaction   672.665      2    165  336.333  9.237    0.000  0.101  nan

# %%
Half0 = data[(data.half == 0)]
Half1 = data[(data.half == 1)]
Stimulus = data[(data.group == 0)]  
Silent = data[(data.group == 1)] 
Open = data[(data.group == 2)] 
Day0 = data[(data.test_day == 0)]  
Day1 = data[(data.test_day == 1)]  
Day2 = data[(data.test_day == 2)] 


Stimulusday0 = data[(data.group == 0)& (data.test_day == 0)] 
Stimulusday1 = data[(data.group == 0)& (data.test_day == 1)] 
Stimulusday2 = data[(data.group == 0)& (data.test_day == 2)] 


Silentday0 = data[(data.group == 1)& (data.test_day == 0)] 
Silentday1 = data[(data.group == 1)& (data.test_day == 1)] 
Silentday2 = data[(data.group == 1)& (data.test_day == 2)]

# %%
aov = pg.anova(data=Half0, dv=('normace'), between='group', detailed = True)
pg.print_table(aov)
# Out:
# =============
# ANOVA SUMMARY
# =============
#
# Source            SS    DF       MS        F    p-unc      np2
# --------  ----------  ----  -------  -------  -------  -------
# group        906.929     2  453.464    2.072    0.127    0.008
# Within    105932.451   484  218.869  nan      nan      nan

# %%
pg.pairwise_gameshowell(data =Half0, dv='normace', between='group').round(3)
# Out:
#    A  B  mean(A)  mean(B)   diff     se      T       df   pval  hedges
# 0  0  1   -5.633   -4.809 -0.824  1.502 -0.548  267.191  0.831  -0.059
# 1  0  2   -5.633   -2.283 -3.350  1.835 -1.826  195.485  0.164  -0.204
# 2  1  2   -4.809   -2.283 -2.526  2.016 -1.253  230.340  0.425  -0.156

# %%
aov = pg.anova(data=Half1, dv=('normace'), between='group', detailed = True)
pg.print_table(aov)
# Out:
# =============
# ANOVA SUMMARY
# =============
#
# Source           SS    DF        MS        F    p-unc      np2
# --------  ---------  ----  --------  -------  -------  -------
# group      5813.227     2  2906.613   18.096    0.000    0.070
# Within    77582.312   483   160.626  nan      nan      nan

# %%
Stimulus0 = data[(data.group == 0)& (data.half == 0)] 
Stimulus0 = Stimulus0[1:]
Stimulus1 = data[(data.group == 0)& (data.half == 1)] 
stats.ttest_rel(Stimulus0['normace'], Stimulus1['normace'])
# Out:
# Ttest_relResult(statistic=3.2118177362765583, pvalue=0.0015084625516552234)

# %%
Stimulus1 = data[(data.group == 0)& (data.half == 1)] 
stats.ttest_rel(Stimulus0['normace'], Stimulus1['normace'])
Silent0 = data[(data.group == 1)& (data.half == 0)] 
#Silent0 = Silent0[1:]
Silent1 = data[(data.group == 1)& (data.half == 1)] 
stats.ttest_rel(Silent0['normace'], Silent1['normace'])
# Out:
# Ttest_relResult(statistic=-2.305246513877045, pvalue=0.022700850843330865)

# %%
Open0 = data[(data.group == 2)& (data.half == 0)] 
#Silent0 = Silent0[1:]
Open1 = data[(data.group == 2)& (data.half == 1)] 
stats.ttest_rel(Open0['normace'], Open1['normace'])
# Out:
# Ttest_relResult(statistic=-0.7932111460791383, pvalue=0.42920747004412807)

# %%
pg.pairwise_gameshowell(data =Half1, dv='normace', between='group').round(3)
# Out:
#    A  B  mean(A)  mean(B)   diff     se      T       df   pval  hedges
# 0  0  1   -8.669   -1.871 -6.798  1.173 -5.795  288.862  0.001  -0.628
# 1  0  2   -8.669   -1.606 -7.063  1.692 -4.174  178.239  0.001  -0.466
# 2  1  2   -1.871   -1.606 -0.265  1.779 -0.149  200.322  0.900  -0.019

# %%
aov = pg.mixed_anova(data=Half1, dv=('normace'), subject=('id'), between='group', 
                     within= ('test_day'),
                     correction = True, effsize='np2')
pg.print_table(aov)
# Out:
# =============
# ANOVA SUMMARY
# =============
#
# Source             SS    DF1    DF2        MS       F    p-unc    p-GG-corr    np2      eps    sphericity    W-spher    p-spher
# -----------  --------  -----  -----  --------  ------  -------  -----------  -----  -------  ------------  ---------  ---------
# group        5366.505      2    164  2683.252  12.125    0.000      nan      0.129  nan           nan        nan        nan
# test_day      221.091      2    328   110.546   0.971    0.380        0.382  0.006    0.998         1.000      0.998      0.881
# Interaction   721.836      4    328   180.459   1.585    0.178      nan      0.019  nan           nan        nan        nan

# %%
pg.pairwise_gameshowell(data =Half1, dv='normace', between='group').round(3)
# Out:
#    A  B  mean(A)  mean(B)   diff     se      T       df   pval  hedges
# 0  0  1   -8.669   -1.871 -6.798  1.173 -5.795  288.862  0.001  -0.628
# 1  0  2   -8.669   -1.606 -7.063  1.692 -4.174  178.239  0.001  -0.466
# 2  1  2   -1.871   -1.606 -0.265  1.779 -0.149  200.322  0.900  -0.019

# %%
d = {'group': data[(      'group', '')], 'score': data[(     'normace', '')], 
     'id': data[(         'id', '')], 'test_day': data[(   'test_day', '')], 
     'session_num': data[('session_num', '')], 'half': data[(       'half', '')]}
ad = pd.DataFrame(data=d)
ad.columns
ad['stim']= np.where((ad['group'] == 0), 1, 0) 
ad['sil']= np.where((ad['group'] == 1), 1, 0) 
ad['nf']= np.where((ad['group'] == 2), 1, 0)

# %%
labels = data.group.unique()
x_pos = np.arange(len(labels))
x = ad['group']
y = ad['score']
hue = ad['half']
sns.set(style="darkgrid")
ax = sns.boxplot(data=ad, x=x, y=y, hue=hue, palette="Set2", showfliers=False, showmeans = True, 
                 meanprops={"markerfacecolor":"black", 
                       "markeredgecolor":"black",
                      "markersize":"5"})
ax.set_xticks(x_pos)
ax.set_xticklabels(("Stimulus", "Silent", "No- \n feedback"))
#ax.set_title('Pong Performance By \n Condition & Time')
ax.set_ylabel('Aces vs Rest (%)')
ax.set_xlabel('Group')
ax.grid(False)
ax.legend([0, 1], ["0-5", "6-20"])
L = plt.legend(loc='lower left', bbox_to_anchor=(-0.2, -0.5), title = "Minutes", borderaxespad=0.1, frameon=False)
L.get_texts()[0].set_text('0-5')
L.get_texts()[1].set_text('6-20')

y, h, col = 40, 2, 'k'
x00, x01 = -.2, .2
x10, x11 = .8, 1.2
x20, x21 = 1.8, 2.2
#Plot t-test between groups
plt.plot([x00, x00, x01, x01], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text(((x00 + x01)/2), y+ h, "**", ha='center', va='bottom', color=col, fontsize=8)

#Plot differences between groups time 2
plt.text(x11, y-10, "###", ha='center', va='bottom', color=col,  fontsize=8)

plt.text(x21, y, "###", ha='center', va='bottom', color=col, fontsize=8)



# Plot extra legend
#plt.text(4.4, 1.38, "#=p<0.01 \n vs Stimulus", ha='center', va='bottom', color=col)
#plt.text(4.4, 1.15, "#=p<0.05 \n vs Stimulus", ha='center', va='bottom', color=col)
#plt.text(4.4, .92, "%%=p<0.01  \n vs Silent", ha='center', va='bottom', color=col)
#plt.text(4.4, .69, "%=p<0.05  \n vs Silent", ha='center', va='bottom', color=col)

ax.set_ylim([-50, 50])
sns.set(rc={'figure.figsize':(3,3)})

#plt.savefig('/home/jovyan/work/dishpill/Analysis/Plots/feedback_ace_sig.pdf', bbox_inches='tight')

# %%
labels = data.test_day.unique()
x_pos = np.arange(len(labels))
x = Half1['test_day']
y = Half1['normace']
hue = Half1['group']
sns.set(style="darkgrid")
ax = sns.lineplot(data=data, x=x, y=y, hue=hue, palette="Set2", err_style = "band", ci= 68)
L = plt.legend(loc='lower left', bbox_to_anchor=(-0.2, -0.6), title = "Condition", borderaxespad=0.1, frameon=False, ncol = 2)
L.get_texts()[0].set_text('Stimulus')
L.get_texts()[1].set_text('Silent')
L.get_texts()[2].set_text('No-feedback')
ax.grid(False)
ax.set_xticks(x_pos)
ax.set_xticklabels(("1", "2", "3"))
#ax.set_title('Pong Performance By \n Condition & Time')
ax.set_ylabel('Aces vs Rest (%)')
ax.set_xlabel('Day of Testing')
#ax.set_ylim([0.6, 1])
ax.set_xlim([0, 2.4])

plt.text(2.2, -2.2, "###", ha='center', va='bottom', color=col,  fontsize=8)

plt.text(2.2, -3.2, "###", ha='center', va='bottom', color=col, fontsize=8)


#plt.savefig('/home/jovyan/work/dishpill/Analysis/Plots/feedback_ace_days_sig.pdf', bbox_inches='tight')
# Out:
# Text(2.2, -3.2, '###')

# %%
#normalises only by group for long_rally
filtdf = df.groupby(['group', 'tag', 'chip_id', 'test_day', 'session_num', 'half', "control", 'elapse_minute_rounded']).mean()
data = filtdf.reset_index()
data = data.groupby(['group', 'tag', 'chip_id', 'test_day', 'half', 'session_num', "control"]).mean()
data = data[['long_rally']].copy()
data = data.unstack(level=6)
data=data.sort_values(by=["group", "tag", "chip_id", "test_day", "half",])
data[('long_rally', 1)] = data[('long_rally', 1)].fillna(method='ffill', inplace=False)
data = data.dropna()
#data['long_rally', 0]= np.where((data['long_rally', 0] == 0.000000), 0.000001, data['long_rally', 0]) 
#data['long_rally', 1]= np.where((data['long_rally', 1] == 0.000000), 0.000001, data['long_rally', 1]) 
data["normlr"] = (data[('long_rally', 0)] - data[('long_rally', 1)]) * 100 # / data[('long_rally', 1)] ) *100
data = data.dropna()
data = data.reset_index()

data['test_day']= np.where((data['test_day'] == 4), 0, data['test_day']) 
data['test_day']= np.where((data['test_day'] == 5), 1, data['test_day']) 
data['test_day']= np.where((data['test_day'] == 6), 2, data['test_day']) 
data['test_day']= np.where((data['test_day'] == 7), 0, data['test_day']) 
data['test_day']= np.where((data['test_day'] == 8), 1, data['test_day']) 
data['test_day']= np.where((data['test_day'] == 9), 2, data['test_day']) 
data['session_num']= np.where((data['test_day'] == 1) & (data['session_num'] == 0), 3, data['session_num']) 
data['session_num']= np.where((data['test_day'] == 1)& (data['session_num'] == 1), 4, data['session_num']) 
data['session_num']= np.where((data['test_day'] == 1)& (data['session_num'] == 2), 5, data['session_num']) 
data['session_num']= np.where((data['test_day'] == 2)& (data['session_num'] == 0), 6, data['session_num']) 
data['session_num']= np.where((data['test_day'] == 2)& (data['session_num'] == 1), 7, data['session_num']) 
data['session_num']= np.where((data['test_day'] == 2)& (data['session_num'] == 2), 8, data['session_num']) 


data["id"] = ((data['group']).astype(str) + (data['chip_id']).astype(str)) + ((data['session_num']).astype(str))
data = data[(data.group != 4)]
data = data[(data.test_day != 3)]


data[200:400]
#data.chip_id.unique()
# Out:
#         group                                  tag chip_id test_day half  \
# control
# 218         0                 GFP_rate_code-reseed   11610      0.0    0
# 219         0                 GFP_rate_code-reseed   11610      0.0    1
# 220         0                 GFP_rate_code-reseed   11610      0.0    1
# 221         0                 GFP_rate_code-reseed   11610      0.0    1
# 222         0                 GFP_rate_code-reseed   11610      1.0    0
# 223         0                 GFP_rate_code-reseed   11610      1.0    0
# 224         0                 GFP_rate_code-reseed   11610      1.0    0
# 225         0                 GFP_rate_code-reseed   11610      1.0    1
# 226         0                 GFP_rate_code-reseed   11610      1.0    1
# 227         0                 GFP_rate_code-reseed   11610      1.0    1
# 228         0                 GFP_rate_code-reseed   11610      2.0    0
# 229         0                 GFP_rate_code-reseed   11610      2.0    0
# 230         0                 GFP_rate_code-reseed   11610      2.0    0
# 231         0                 GFP_rate_code-reseed   11610      2.0    1
# 232         0                 GFP_rate_code-reseed   11610      2.0    1
# 233         0                 GFP_rate_code-reseed   11610      2.0    1
# 234         0                 GFP_rate_code-reseed   11613      1.0    0
# 235         0                 GFP_rate_code-reseed   11613      1.0    0
# 236         0                 GFP_rate_code-reseed   11613      1.0    0
# 237         0                 GFP_rate_code-reseed   11613      1.0    1
# 238         0                 GFP_rate_code-reseed   11613      1.0    1
# 239         0                 GFP_rate_code-reseed   11613      1.0    1
# 240         0                 GFP_rate_code-reseed   11613      2.0    0
# 241         0                 GFP_rate_code-reseed   11613      2.0    0
# 242         0                 GFP_rate_code-reseed   11613      2.0    0
# 243         0                 GFP_rate_code-reseed   11613      2.0    1
# 244         0                 GFP_rate_code-reseed   11613      2.0    1
# 245         0                 GFP_rate_code-reseed   11613      2.0    1
# 252         0                 GFP_rate_code_reseed   11570      0.0    0
# 253         0                 GFP_rate_code_reseed   11570      0.0    0
# 254         0                 GFP_rate_code_reseed   11570      0.0    0
# 255         0                 GFP_rate_code_reseed   11570      0.0    1
# 256         0                 GFP_rate_code_reseed   11570      0.0    1
# 257         0                 GFP_rate_code_reseed   11570      0.0    1
# 258         0                 GFP_rate_code_reseed   11570      1.0    0
# 259         0                 GFP_rate_code_reseed   11570      1.0    0
# 260         0                 GFP_rate_code_reseed   11570      1.0    0
# 261         0                 GFP_rate_code_reseed   11570      1.0    1
# 262         0                 GFP_rate_code_reseed   11570      1.0    1
# 263         0                 GFP_rate_code_reseed   11570      1.0    1
# 264         0                 GFP_rate_code_reseed   11570      2.0    0
# 265         0                 GFP_rate_code_reseed   11570      2.0    0
# 266         0                 GFP_rate_code_reseed   11570      2.0    0
# 267         0                 GFP_rate_code_reseed   11570      2.0    1
# 268         0                 GFP_rate_code_reseed   11570      2.0    1
# 269         0                 GFP_rate_code_reseed   11570      2.0    1
# 276         0                 GFP_rate_code_reseed   11609      2.0    0
# 277         0                 GFP_rate_code_reseed   11609      2.0    0
# 278         0                 GFP_rate_code_reseed   11609      2.0    0
# 279         0                 GFP_rate_code_reseed   11609      2.0    1
# 280         0                 GFP_rate_code_reseed   11609      2.0    1
# 281         0                 GFP_rate_code_reseed   11609      2.0    1
# 282         0                 GFP_rate_code_reseed   11618      1.0    0
# 283         0                 GFP_rate_code_reseed   11618      1.0    0
# 284         0                 GFP_rate_code_reseed   11618      1.0    0
# 285         0                 GFP_rate_code_reseed   11618      1.0    1
# 286         0                 GFP_rate_code_reseed   11618      1.0    1
# 287         0                 GFP_rate_code_reseed   11618      1.0    1
# 288         0                 GFP_rate_code_reseed   11618      2.0    0
# 289         0                 GFP_rate_code_reseed   11618      2.0    0
# 290         0                 GFP_rate_code_reseed   11618      2.0    0
# 291         0                 GFP_rate_code_reseed   11618      2.0    1
# 292         0                 GFP_rate_code_reseed   11618      2.0    1
# 293         0                 GFP_rate_code_reseed   11618      2.0    1
# 300         0                      GFP_test_reseed   11623      1.0    0
# 301         0                      GFP_test_reseed   11623      1.0    0
# 302         0                      GFP_test_reseed   11623      1.0    1
# 303         0                      GFP_test_reseed   11623      1.0    1
# 304         0  ngn2_test_rate_code_random_3_reseed   12106      0.0    0
# 305         0  ngn2_test_rate_code_random_3_reseed   12106      0.0    0
# 306         0  ngn2_test_rate_code_random_3_reseed   12106      0.0    0
# 307         0  ngn2_test_rate_code_random_3_reseed   12106      0.0    1
# 308         0  ngn2_test_rate_code_random_3_reseed   12106      0.0    1
# 309         0  ngn2_test_rate_code_random_3_reseed   12106      0.0    1
# 310         0  ngn2_test_rate_code_random_3_reseed   12106      1.0    0
# 311         0  ngn2_test_rate_code_random_3_reseed   12123      0.0    0
# 312         0  ngn2_test_rate_code_random_3_reseed   12123      0.0    0
# 313         0  ngn2_test_rate_code_random_3_reseed   12123      0.0    0
# 314         0  ngn2_test_rate_code_random_3_reseed   12123      0.0    1
# 315         0  ngn2_test_rate_code_random_3_reseed   12123      0.0    1
# 316         0  ngn2_test_rate_code_random_3_reseed   12123      0.0    1
# 317         0  ngn2_test_rate_code_random_3_reseed   12123      1.0    0
# 318         0  ngn2_test_rate_code_random_3_reseed   12123      1.0    0
# 319         0  ngn2_test_rate_code_random_3_reseed   12123      1.0    0
# 320         0  ngn2_test_rate_code_random_3_reseed   12123      1.0    1
# 321         0  ngn2_test_rate_code_random_3_reseed   12123      1.0    1
# 322         0  ngn2_test_rate_code_random_3_reseed   12123      1.0    1
# 323         0  ngn2_test_rate_code_random_3_reseed   12123      2.0    0
# 324         0  ngn2_test_rate_code_random_3_reseed   12123      2.0    0
# 325         0  ngn2_test_rate_code_random_3_reseed   12123      2.0    0
# 326         0  ngn2_test_rate_code_random_3_reseed   12123      2.0    1
# 327         0  ngn2_test_rate_code_random_3_reseed   12123      2.0    1
# 328         0  ngn2_test_rate_code_random_3_reseed   12123      2.0    1
# 329         0  ngn2_test_rate_code_random_3_reseed   12138      0.0    0
# 330         0  ngn2_test_rate_code_random_3_reseed   12138      0.0    0
# 331         0  ngn2_test_rate_code_random_3_reseed   12138      0.0    0
# 332         0  ngn2_test_rate_code_random_3_reseed   12138      0.0    1
# 333         0  ngn2_test_rate_code_random_3_reseed   12138      0.0    1
# 334         0  ngn2_test_rate_code_random_3_reseed   12138      0.0    1
# 335         0  ngn2_test_rate_code_random_3_reseed   12138      1.0    0
# 336         0  ngn2_test_rate_code_random_3_reseed   12138      1.0    0
# 337         0  ngn2_test_rate_code_random_3_reseed   12138      1.0    0
# 338         0  ngn2_test_rate_code_random_3_reseed   12138      1.0    1
# 339         0  ngn2_test_rate_code_random_3_reseed   12138      1.0    1
# 340         0  ngn2_test_rate_code_random_3_reseed   12138      1.0    1
# 341         0  ngn2_test_rate_code_random_3_reseed   12138      2.0    0
# 342         0  ngn2_test_rate_code_random_3_reseed   12138      2.0    0
# 343         0  ngn2_test_rate_code_random_3_reseed   12138      2.0    0
# 344         0  ngn2_test_rate_code_random_3_reseed   12138      2.0    1
# 345         0  ngn2_test_rate_code_random_3_reseed   12138      2.0    1
# 346         0  ngn2_test_rate_code_random_3_reseed   12138      2.0    1
# 347         0  ngn2_test_rate_code_random_3_reseed   12160      0.0    0
# 348         0  ngn2_test_rate_code_random_3_reseed   12160      0.0    0
# 349         0  ngn2_test_rate_code_random_3_reseed   12160      0.0    0
# 350         0  ngn2_test_rate_code_random_3_reseed   12160      0.0    1
# 351         0  ngn2_test_rate_code_random_3_reseed   12160      0.0    1
# 352         0  ngn2_test_rate_code_random_3_reseed   12160      0.0    1
# 353         0  ngn2_test_rate_code_random_3_reseed   12250      0.0    0
# 354         0  ngn2_test_rate_code_random_3_reseed   12250      0.0    0
# 355         0  ngn2_test_rate_code_random_3_reseed   12250      0.0    0
# 356         0  ngn2_test_rate_code_random_3_reseed   12250      0.0    1
# 357         0  ngn2_test_rate_code_random_3_reseed   12250      0.0    1
# 358         0  ngn2_test_rate_code_random_3_reseed   12250      0.0    1
# 359         0  ngn2_test_rate_code_random_3_reseed   12250      1.0    0
# 360         0  ngn2_test_rate_code_random_3_reseed   12250      1.0    0
# 361         0  ngn2_test_rate_code_random_3_reseed   12250      1.0    0
# 362         0  ngn2_test_rate_code_random_3_reseed   12250      1.0    1
# 363         0  ngn2_test_rate_code_random_3_reseed   12250      1.0    1
# 364         0  ngn2_test_rate_code_random_3_reseed   12250      1.0    1
# 365         0  ngn2_test_rate_code_random_3_reseed   12250      2.0    0
# 366         0  ngn2_test_rate_code_random_3_reseed   12250      2.0    0
# 367         0  ngn2_test_rate_code_random_3_reseed   12250      2.0    0
# 368         0  ngn2_test_rate_code_random_3_reseed   12250      2.0    1
# 369         0  ngn2_test_rate_code_random_3_reseed   12250      2.0    1
# 370         0  ngn2_test_rate_code_random_3_reseed   12250      2.0    1
# 371         0  ngn2_test_rate_code_random_3_reseed   12265      0.0    0
# 372         0  ngn2_test_rate_code_random_3_reseed   12265      0.0    0
# 373         0  ngn2_test_rate_code_random_3_reseed   12265      0.0    0
# 374         0  ngn2_test_rate_code_random_3_reseed   12265      0.0    1
# 375         0  ngn2_test_rate_code_random_3_reseed   12265      0.0    1
# 376         0  ngn2_test_rate_code_random_3_reseed   12265      0.0    1
# 377         0  ngn2_test_rate_code_random_3_reseed   12265      1.0    0
# 378         0  ngn2_test_rate_code_random_3_reseed   12265      1.0    0
# 379         0  ngn2_test_rate_code_random_3_reseed   12265      1.0    0
# 380         0  ngn2_test_rate_code_random_3_reseed   12265      1.0    1
# 381         0  ngn2_test_rate_code_random_3_reseed   12265      1.0    1
# 382         0  ngn2_test_rate_code_random_3_reseed   12265      1.0    1
# 383         0  ngn2_test_rate_code_random_3_reseed   12265      2.0    0
# 384         0  ngn2_test_rate_code_random_3_reseed   12265      2.0    0
# 385         0  ngn2_test_rate_code_random_3_reseed   12265      2.0    0
# 386         0  ngn2_test_rate_code_random_3_reseed   12265      2.0    1
# 387         0  ngn2_test_rate_code_random_3_reseed   12265      2.0    1
# 388         0  ngn2_test_rate_code_random_3_reseed   12265      2.0    1
# 389         0  ngn2_test_rate_code_random_3_reseed   12285      0.0    0
# 390         0  ngn2_test_rate_code_random_3_reseed   12285      0.0    0
# 391         0  ngn2_test_rate_code_random_3_reseed   12285      0.0    0
# 392         0  ngn2_test_rate_code_random_3_reseed   12285      0.0    1
# 393         0  ngn2_test_rate_code_random_3_reseed   12285      0.0    1
# 394         0  ngn2_test_rate_code_random_3_reseed   12285      0.0    1
# 395         0  ngn2_test_rate_code_random_3_reseed   12285      1.0    0
# 396         0  ngn2_test_rate_code_random_3_reseed   12285      1.0    0
# 397         0  ngn2_test_rate_code_random_3_reseed   12285      1.0    0
# 398         0  ngn2_test_rate_code_random_3_reseed   12285      1.0    1
# 399         0  ngn2_test_rate_code_random_3_reseed   12285      1.0    1
# 400         0  ngn2_test_rate_code_random_3_reseed   12285      1.0    1
# 401         0  ngn2_test_rate_code_random_3_reseed   12285      2.0    0
# 402         0  ngn2_test_rate_code_random_3_reseed   12285      2.0    0
# 403         0  ngn2_test_rate_code_random_3_reseed   12285      2.0    0
# 404         0  ngn2_test_rate_code_random_3_reseed   12285      2.0    1
# 405         0  ngn2_test_rate_code_random_3_reseed   12285      2.0    1
# 406         0  ngn2_test_rate_code_random_3_reseed   12285      2.0    1
# 407         0         prim_test_rate_code_random_3   11614      0.0    0
# 408         0         prim_test_rate_code_random_3   11614      0.0    0
# 409         0         prim_test_rate_code_random_3   11614      0.0    0
# 410         0         prim_test_rate_code_random_3   11614      0.0    1
# 411         0         prim_test_rate_code_random_3   11614      0.0    1
# 412         0         prim_test_rate_code_random_3   11614      0.0    1
# 413         0         prim_test_rate_code_random_3   11614      1.0    0
# 414         0         prim_test_rate_code_random_3   11614      1.0    0
# 415         0         prim_test_rate_code_random_3   11614      1.0    0
# 416         0         prim_test_rate_code_random_3   11614      1.0    1
# 417         0         prim_test_rate_code_random_3   11614      1.0    1
# 418         0         prim_test_rate_code_random_3   11614      1.0    1
# 419         0         prim_test_rate_code_random_3   11614      2.0    0
# 420         0         prim_test_rate_code_random_3   11614      2.0    0
# 421         0         prim_test_rate_code_random_3   11614      2.0    0
# 422         0         prim_test_rate_code_random_3   11614      2.0    1
# 423         0         prim_test_rate_code_random_3   11614      2.0    1
# 424         0         prim_test_rate_code_random_3   11614      2.0    1
# 425         0         prim_test_rate_code_random_3   11619      0.0    0
# 426         0         prim_test_rate_code_random_3   11619      0.0    0
# 427         0         prim_test_rate_code_random_3   11619      0.0    0
# 428         0         prim_test_rate_code_random_3   11619      0.0    1
# 429         0         prim_test_rate_code_random_3   11619      0.0    1
# 430         0         prim_test_rate_code_random_3   11619      0.0    1
# 431         0         prim_test_rate_code_random_3   11619      1.0    0
# 432         0         prim_test_rate_code_random_3   11619      1.0    0
# 433         0         prim_test_rate_code_random_3   11619      1.0    0
# 434         0         prim_test_rate_code_random_3   11619      1.0    1
# 435         0         prim_test_rate_code_random_3   11619      1.0    1
#
#         session_num long_rally               normlr         id
# control                      0         1
# 218             3.0   0.000000  0.012500  -1.250000  0116103.0
# 219             1.0   0.116667  0.012500  10.416667  0116101.0
# 220             2.0   0.100000  0.012500   8.750000  0116102.0
# 221             3.0   0.127778  0.012500  11.527778  0116103.0
# 222             4.0   0.066667  0.070833  -0.416667  0116104.0
# 223             5.0   0.066667  0.070833  -0.416667  0116105.0
# 224             3.0   0.050000  0.070833  -2.083333  0116103.0
# 225             4.0   0.066667  0.070833  -0.416667  0116104.0
# 226             5.0   0.161111  0.070833   9.027778  0116105.0
# 227             3.0   0.038889  0.070833  -3.194444  0116103.0
# 228             7.0   0.066667  0.159563  -9.289683  0116107.0
# 229             8.0   0.266667  0.159563  10.710317  0116108.0
# 230             3.0   0.000000  0.159563 -15.956349  0116103.0
# 231             7.0   0.094444  0.159563  -6.511905  0116107.0
# 232             8.0   0.066667  0.159563  -9.289683  0116108.0
# 233             3.0   0.233333  0.159563   7.376984  0116103.0
# 234             4.0   0.000000  0.043452  -4.345238  0116134.0
# 235             5.0   0.066667  0.043452   2.321429  0116135.0
# 236             3.0   0.000000  0.043452  -4.345238  0116133.0
# 237             4.0   0.222222  0.043452  17.876984  0116134.0
# 238             5.0   0.061111  0.043452   1.765873  0116135.0
# 239             3.0   0.059524  0.043452   1.607143  0116133.0
# 240             7.0   0.000000  0.057143  -5.714286  0116137.0
# 241             8.0   0.100000  0.057143   4.285714  0116138.0
# 242             3.0   0.066667  0.057143   0.952381  0116133.0
# 243             7.0   0.055556  0.057143  -0.158730  0116137.0
# 244             8.0   0.080000  0.057143   2.285714  0116138.0
# 245             3.0   0.138889  0.057143   8.174603  0116133.0
# 252             1.0   0.000000  0.039286  -3.928571  0115701.0
# 253             2.0   0.000000  0.039286  -3.928571  0115702.0
# 254             3.0   0.066667  0.039286   2.738095  0115703.0
# 255             1.0   0.157778  0.039286  11.849206  0115701.0
# 256             2.0   0.033333  0.039286  -0.595238  0115702.0
# 257             3.0   0.066667  0.039286   2.738095  0115703.0
# 258             4.0   0.066667  0.141071  -7.440476  0115704.0
# 259             5.0   0.000000  0.141071 -14.107143  0115705.0
# 260             3.0   0.000000  0.141071 -14.107143  0115703.0
# 261             4.0   0.022222  0.141071 -11.884921  0115704.0
# 262             5.0   0.138889  0.141071  -0.218254  0115705.0
# 263             3.0   0.072222  0.141071  -6.884921  0115703.0
# 264             7.0   0.000000  0.195516 -19.551587  0115707.0
# 265             8.0   0.050000  0.195516 -14.551587  0115708.0
# 266             3.0   0.116667  0.195516  -7.884921  0115703.0
# 267             7.0   0.100000  0.195516  -9.551587  0115707.0
# 268             8.0   0.000000  0.195516 -19.551587  0115708.0
# 269             3.0   0.055556  0.195516 -13.996032  0115703.0
# 276             7.0   0.000000  0.072619  -7.261905  0116097.0
# 277             8.0   0.200000  0.072619  12.738095  0116098.0
# 278             3.0   0.095717  0.072619   2.309762  0116093.0
# 279             7.0   0.022222  0.072619  -5.039683  0116097.0
# 280             8.0   0.083333  0.072619   1.071429  0116098.0
# 281             3.0   0.098058  0.072619   2.543896  0116093.0
# 282             4.0   0.050000  0.087857  -3.785714  0116184.0
# 283             5.0   0.100000  0.087857   1.214286  0116185.0
# 284             3.0   0.066667  0.087857  -2.119048  0116183.0
# 285             4.0   0.122222  0.087857   3.436508  0116184.0
# 286             5.0   0.055556  0.087857  -3.230159  0116185.0
# 287             3.0   0.077778  0.087857  -1.007937  0116183.0
# 288             7.0   0.000000  0.091071  -9.107143  0116187.0
# 289             8.0   0.066667  0.091071  -2.440476  0116188.0
# 290             3.0   0.066667  0.091071  -2.440476  0116183.0
# 291             7.0   0.038889  0.091071  -5.218254  0116187.0
# 292             8.0   0.066667  0.091071  -2.440476  0116188.0
# 293             3.0   0.033333  0.091071  -5.773810  0116183.0
# 300             5.0   0.116667  0.102619   1.404762  0116235.0
# 301             3.0   0.050000  0.102619  -5.261905  0116233.0
# 302             5.0   0.066667  0.102619  -3.595238  0116235.0
# 303             3.0   0.093889  0.102619  -0.873016  0116233.0
# 304             1.0   0.066667  0.043452   2.321429  0121061.0
# 305             2.0   0.066667  0.043452   2.321429  0121062.0
# 306             3.0   0.200000  0.043452  15.654762  0121063.0
# 307             1.0   0.144444  0.043452  10.099206  0121061.0
# 308             2.0   0.166667  0.043452  12.321429  0121062.0
# 309             3.0   0.111111  0.043452   6.765873  0121063.0
# 310             4.0   0.000000  0.043452  -4.345238  0121064.0
# 311             1.0   0.366667  0.070238  29.642857  0121231.0
# 312             2.0   0.166667  0.070238   9.642857  0121232.0
# 313             3.0   0.183333  0.070238  11.309524  0121233.0
# 314             1.0   0.050000  0.070238  -2.023810  0121231.0
# 315             2.0   0.035556  0.070238  -3.468254  0121232.0
# 316             3.0   0.038889  0.070238  -3.134921  0121233.0
# 317             4.0   0.166667  0.069167   9.750000  0121234.0
# 318             5.0   0.116667  0.069167   4.750000  0121235.0
# 319             3.0   0.066667  0.069167  -0.250000  0121233.0
# 320             4.0   0.068889  0.069167  -0.027778  0121234.0
# 321             5.0   0.061111  0.069167  -0.805556  0121235.0
# 322             3.0   0.083333  0.069167   1.416667  0121233.0
# 323             7.0   0.100000  0.066667   3.333333  0121237.0
# 324             8.0   0.000000  0.066667  -6.666667  0121238.0
# 325             3.0   0.066667  0.066667   0.000000  0121233.0
# 326             7.0   0.105556  0.066667   3.888889  0121237.0
# 327             8.0   0.038889  0.066667  -2.777778  0121238.0
# 328             3.0   0.100000  0.066667   3.333333  0121233.0
# 329             1.0   0.000000  0.079524  -7.952381  0121381.0
# 330             2.0   0.116667  0.079524   3.714286  0121382.0
# 331             3.0   0.166667  0.079524   8.714286  0121383.0
# 332             1.0   0.138889  0.079524   5.936508  0121381.0
# 333             2.0   0.288889  0.079524  20.936508  0121382.0
# 334             3.0   0.094444  0.079524   1.492063  0121383.0
# 335             4.0   0.291667  0.077489  21.417749  0121384.0
# 336             5.0   0.100000  0.077489   2.251082  0121385.0
# 337             3.0   0.166667  0.077489   8.917749  0121383.0
# 338             4.0   0.077778  0.077489   0.028860  0121384.0
# 339             5.0   0.148810  0.077489   7.132035  0121385.0
# 340             3.0   0.136905  0.077489   5.941558  0121383.0
# 341             7.0   0.000000  0.033333  -3.333333  0121387.0
# 342             8.0   0.000000  0.033333  -3.333333  0121388.0
# 343             3.0   0.000000  0.033333  -3.333333  0121383.0
# 344             7.0   0.155556  0.033333  12.222222  0121387.0
# 345             8.0   0.147436  0.033333  11.410256  0121388.0
# 346             3.0   0.152222  0.033333  11.888889  0121383.0
# 347             1.0   0.066667  0.030952   3.571429  0121601.0
# 348             2.0   0.066667  0.030952   3.571429  0121602.0
# 349             3.0   0.150000  0.030952  11.904762  0121603.0
# 350             1.0   0.183333  0.030952  15.238095  0121601.0
# 351             2.0   0.050000  0.030952   1.904762  0121602.0
# 352             3.0   0.055556  0.030952   2.460317  0121603.0
# 353             1.0   0.050000  0.097619  -4.761905  0122501.0
# 354             2.0   0.000000  0.097619  -9.761905  0122502.0
# 355             3.0   0.000000  0.097619  -9.761905  0122503.0
# 356             1.0   0.142857  0.097619   4.523810  0122501.0
# 357             2.0   0.272222  0.097619  17.460317  0122502.0
# 358             3.0   0.130952  0.097619   3.333333  0122503.0
# 359             4.0   0.166667  0.024286  14.238095  0122504.0
# 360             5.0   0.266667  0.024286  24.238095  0122505.0
# 361             3.0   0.150000  0.024286  12.571429  0122503.0
# 362             4.0   0.222222  0.024286  19.793651  0122504.0
# 363             5.0   0.072222  0.024286   4.793651  0122505.0
# 364             3.0   0.216667  0.024286  19.238095  0122503.0
# 365             7.0   0.133333  0.033333  10.000000  0122507.0
# 366             8.0   0.066667  0.033333   3.333333  0122508.0
# 367             3.0   0.000000  0.033333  -3.333333  0122503.0
# 368             7.0   0.180000  0.033333  14.666667  0122507.0
# 369             8.0   0.127778  0.033333   9.444444  0122508.0
# 370             3.0   0.188889  0.033333  15.555556  0122503.0
# 371             1.0   0.066667  0.117024  -5.035714  0122651.0
# 372             2.0   0.133333  0.117024   1.630952  0122652.0
# 373             3.0   0.025000  0.117024  -9.202381  0122653.0
# 374             1.0   0.091111  0.117024  -2.591270  0122651.0
# 375             2.0   0.022222  0.117024  -9.480159  0122652.0
# 376             3.0   0.084896  0.117024  -3.212787  0122653.0
# 377             4.0   0.066667  0.000000   6.666667  0122654.0
# 378             5.0   0.000000  0.000000   0.000000  0122655.0
# 379             3.0   0.000000  0.000000   0.000000  0122653.0
# 380             4.0   0.044444  0.000000   4.444444  0122654.0
# 381             5.0   0.138889  0.000000  13.888889  0122655.0
# 382             3.0   0.061111  0.000000   6.111111  0122653.0
# 383             7.0   0.000000  0.056508  -5.650794  0122657.0
# 384             8.0   0.100000  0.056508   4.349206  0122658.0
# 385             3.0   0.000000  0.056508  -5.650794  0122653.0
# 386             7.0   0.088889  0.056508   3.238095  0122657.0
# 387             8.0   0.072222  0.056508   1.571429  0122658.0
# 388             3.0   0.055556  0.056508  -0.095238  0122653.0
# 389             1.0   0.066667  0.107857  -4.119048  0122851.0
# 390             2.0   0.000000  0.107857 -10.785714  0122852.0
# 391             3.0   0.200000  0.107857   9.214286  0122853.0
# 392             1.0   0.277778  0.107857  16.992063  0122851.0
# 393             2.0   0.138889  0.107857   3.103175  0122852.0
# 394             3.0   0.107778  0.107857  -0.007937  0122853.0
# 395             4.0   0.200000  0.087619  11.238095  0122854.0
# 396             5.0   0.233333  0.087619  14.571429  0122855.0
# 397             3.0   0.066667  0.087619  -2.095238  0122853.0
# 398             4.0   0.033333  0.087619  -5.428571  0122854.0
# 399             5.0   0.166667  0.087619   7.904762  0122855.0
# 400             3.0   0.155556  0.087619   6.793651  0122853.0
# 401             7.0   0.000000  0.074098  -7.409812  0122857.0
# 402             8.0   0.066667  0.074098  -0.743146  0122858.0
# 403             3.0   0.040000  0.074098  -3.409812  0122853.0
# 404             7.0   0.161111  0.074098   8.701299  0122857.0
# 405             8.0   0.033333  0.074098  -4.076479  0122858.0
# 406             3.0   0.105556  0.074098   3.145743  0122853.0
# 407             1.0   0.000000  0.102143 -10.214286  0116141.0
# 408             2.0   0.166667  0.102143   6.452381  0116142.0
# 409             3.0   0.000000  0.102143 -10.214286  0116143.0
# 410             1.0   0.144444  0.102143   4.230159  0116141.0
# 411             2.0   0.208333  0.102143  10.619048  0116142.0
# 412             3.0   0.055556  0.102143  -4.658730  0116143.0
# 413             4.0   0.066667  0.138571  -7.190476  0116144.0
# 414             5.0   0.066667  0.138571  -7.190476  0116145.0
# 415             3.0   0.000000  0.138571 -13.857143  0116143.0
# 416             4.0   0.205556  0.138571   6.698413  0116144.0
# 417             5.0   0.080000  0.138571  -5.857143  0116145.0
# 418             3.0   0.155556  0.138571   1.698413  0116143.0
# 419             7.0   0.066667  0.064286   0.238095  0116147.0
# 420             8.0   0.000000  0.064286  -6.428571  0116148.0
# 421             3.0   0.066667  0.064286   0.238095  0116143.0
# 422             7.0   0.155556  0.064286   9.126984  0116147.0
# 423             8.0   0.191111  0.064286  12.682540  0116148.0
# 424             3.0   0.083333  0.064286   1.904762  0116143.0
# 425             1.0   0.000000  0.060119  -6.011905  0116191.0
# 426             2.0   0.066667  0.060119   0.654762  0116192.0
# 427             3.0   0.000000  0.060119  -6.011905  0116193.0
# 428             1.0   0.111111  0.060119   5.099206  0116191.0
# 429             2.0   0.191111  0.060119  13.099206  0116192.0
# 430             3.0   0.066667  0.060119   0.654762  0116193.0
# 431             4.0   0.000000  0.050952  -5.095238  0116194.0
# 432             5.0   0.200000  0.050952  14.904762  0116195.0
# 433             3.0   0.000000  0.050952  -5.095238  0116193.0
# 434             4.0   0.116667  0.050952   6.571429  0116194.0
# 435             5.0   0.138889  0.050952   8.793651  0116195.0

# %%
aov = pg.mixed_anova(data=data, dv=('normlr'), subject=('id'), between='group', 
                     within= 'half',
                     correction = True, effsize='np2')
pg.print_table(aov)
# Out:
# =============
# ANOVA SUMMARY
# =============
#
# Source             SS    DF1    DF2        MS       F    p-unc    np2      eps
# -----------  --------  -----  -----  --------  ------  -------  -----  -------
# group         104.015      2    353    52.007   0.650    0.523  0.004  nan
# half         1089.865      1    353  1089.865  29.932    0.000  0.078    1.000
# Interaction   873.872      2    353   436.936  12.000    0.000  0.064  nan

# %%
Stimulus0 = data[(data.group == 0)& (data.half == 0)] 
Stimulus0 = Stimulus0[1:]
Stimulus1 = data[(data.group == 0)& (data.half == 1)] 
print(stats.ttest_rel(Stimulus0['normlr'], Stimulus1['normlr']))
Silent0 = data[(data.group == 1)& (data.half == 0)] 
#Silent0 = Silent0[1:]
Silent1 = data[(data.group == 1)& (data.half == 1)] 
print(stats.ttest_rel(Silent0['normlr'], Silent1['normlr']))
Open0 = data[(data.group == 2)& (data.half == 0)] 
#Silent0 = Silent0[1:]
Open1 = data[(data.group == 2)& (data.half == 1)] 
print(stats.ttest_rel(Open0['normlr'], Open1['normlr']))
# Out:
# Ttest_relResult(statistic=-8.541357927873502, pvalue=1.8710653861371673e-15)
# Ttest_relResult(statistic=-0.44379441978192435, pvalue=0.657912388650317)
# Ttest_relResult(statistic=-0.9174879495261817, pvalue=0.3607121497140996)

# %%
Half0 = data[(data.half == 0)]
Half1 = data[(data.half == 1)]
Stimulus = data[(data.group == 0)]  
Silent = data[(data.group == 1)] 
Open = data[(data.group == 2)] 
Day0 = data[(data.test_day == 0)]  
Day1 = data[(data.test_day == 1)]  
Day2 = data[(data.test_day == 2)] 


Stimulusday0 = data[(data.group == 0)& (data.test_day == 0)] 
Stimulusday1 = data[(data.group == 0)& (data.test_day == 1)] 
Stimulusday2 = data[(data.group == 0)& (data.test_day == 2)] 


Silentday0 = data[(data.group == 1)& (data.test_day == 0)] 
Silentday1 = data[(data.group == 1)& (data.test_day == 1)] 
Silentday2 = data[(data.group == 1)& (data.test_day == 2)]

# %%
aov = pg.anova(data=Half0, dv=('normlr'), between='group', detailed = True)
pg.print_table(aov)
# Out:
# =============
# ANOVA SUMMARY
# =============
#
# Source           SS    DF       MS        F    p-unc      np2
# --------  ---------  ----  -------  -------  -------  -------
# group      1235.415     2  617.708    8.513    0.000    0.034
# Within    35120.571   484   72.563  nan      nan      nan

# %%
pg.pairwise_gameshowell(data =Half0, dv='normlr', between='group').round(3)
# Out:
#    A  B  mean(A)  mean(B)   diff     se      T       df   pval  hedges
# 0  0  1   -1.689    1.800 -3.489  0.959 -3.640  234.350  0.001  -0.394
# 1  0  2   -1.689    1.082 -2.771  0.957 -2.896  215.082  0.012  -0.323
# 2  1  2    1.800    1.082  0.717  1.152  0.623  253.482  0.788   0.078

# %%
aov = pg.anova(data=Half1, dv=('normlr'), between='group', detailed = True)
pg.print_table(aov)
# Out:
# =============
# ANOVA SUMMARY
# =============
#
# Source           SS    DF       MS        F    p-unc      np2
# --------  ---------  ----  -------  -------  -------  -------
# group       325.868     2  162.934    3.219    0.041    0.013
# Within    24448.970   483   50.619  nan      nan      nan

# %%
pg.pairwise_gameshowell(data =Half1, dv='normlr', between='group').round(3)
# Out:
#    A  B  mean(A)  mean(B)   diff     se      T       df   pval  hedges
# 0  0  1    3.480    2.195  1.285  0.794  1.619  250.019  0.240   0.176
# 1  0  2    3.480    1.580  1.900  0.794  2.393  229.450  0.046   0.267
# 2  1  2    2.195    1.580  0.615  0.933  0.659  253.410  0.767   0.082

# %%
aov = pg.mixed_anova(data=Half1, dv=('normlr'), subject=('id'), between='group', 
                     within= 'test_day',
                     correction = True, effsize='np2')
pg.print_table(aov)
# Out:
# =============
# ANOVA SUMMARY
# =============
#
# Source            SS    DF1    DF2       MS       F    p-unc    p-GG-corr     np2      eps    sphericity    W-spher    p-spher
# -----------  -------  -----  -----  -------  ------  -------  -----------  ------  -------  ------------  ---------  ---------
# group        308.891      2    164  154.446   0.490    0.614      nan       0.006  nan           nan        nan        nan
# test_day      43.356      2    328   21.678  -0.244    1.000        1.000  -0.001    0.988         1.000      0.988      0.779
# Interaction  475.117      4    328  118.779  -1.336    1.000      nan      -0.017  nan           nan        nan        nan

# %%
Stimulus = Half1[(Half1.group == 0)]  
Silent = Half1[(Half1.group == 1)] 
Open = Half1[(Half1.group == 2)]

# %%
aov = pg.rm_anova(dv='normlr', within='test_day',
                  subject='id', data=Stimulus, detailed=True,
                  effsize="ng2")
pg.print_table(aov)
# Out:
# =============
# ANOVA SUMMARY
# =============
#
# Source            SS    DF       MS        F    p-unc      ng2      eps
# --------  ----------  ----  -------  -------  -------  -------  -------
# test_day      51.796     2   25.898   -0.314    1.000    0.006    0.990
# Error     -11727.669   142  -82.589  nan      nan      nan      nan

# %%
aov = pg.rm_anova(dv='normlr', within='test_day',
                  subject='id', data=Silent, detailed=True,
                  effsize="ng2")
pg.print_table(aov)
# Out:
# =============
# ANOVA SUMMARY
# =============
#
# Source            SS    DF        MS        F    p-unc      ng2      eps
# --------  ----------  ----  --------  -------  -------  -------  -------
# test_day     245.577     2   122.788   -1.187    1.000    0.032    0.851
# Error     -10134.361    98  -103.412  nan      nan      nan      nan

# %%
aov = pg.rm_anova(dv='normlr', within='test_day',
                  subject='id', data=Open, detailed=True,
                  effsize="ng2")
pg.print_table(aov)
# Out:
# =============
# ANOVA SUMMARY
# =============
#
# Source           SS    DF       MS        F    p-unc      ng2      eps
# --------  ---------  ----  -------  -------  -------  -------  -------
# test_day    221.101     2  110.551   -1.385    1.000    0.034    0.849
# Error     -7023.974    88  -79.818  nan      nan      nan      nan

# %%
d = {'group': data[(      'group', '')], 'score': data[(     'normlr', '')], 
     'id': data[(         'id', '')], 'test_day': data[(   'test_day', '')], 
     'session_num': data[('session_num', '')], 'half': data[(       'half', '')]}
ad = pd.DataFrame(data=d)
ad.columns
ad['stim']= np.where((ad['group'] == 0), 1, 0) 
ad['sil']= np.where((ad['group'] == 1), 1, 0) 
ad['nf']= np.where((ad['group'] == 2), 1, 0)

# %%
ad
# Out:
#       group      score         id  test_day  session_num  half  stim  sil  nf
# 0         0 -14.773810  0115974.0       1.0          4.0     0     1    0   0
# 1         0  -8.107143  0115975.0       1.0          5.0     0     1    0   0
# 2         0  -8.107143  0115973.0       1.0          3.0     0     1    0   0
# 3         0  -8.662698  0115974.0       1.0          4.0     1     1    0   0
# 4         0 -10.329365  0115975.0       1.0          5.0     1     1    0   0
# ...     ...        ...        ...       ...          ...   ...   ...  ...  ..
# 1004      2   2.333333  2131685.0       1.0          5.0     0     0    0   1
# 1005      2   1.666667  2131683.0       1.0          3.0     0     0    0   1
# 1006      2  -0.428571  2131684.0       1.0          4.0     1     0    0   1
# 1007      2  -2.373016  2131685.0       1.0          5.0     1     0    0   1
# 1008      2   7.888889  2131683.0       1.0          3.0     1     0    0   1
#
# [973 rows x 9 columns]

# %%
labels = data.group.unique()
x_pos = np.arange(len(labels))
x = ad['group']
y = ad['score']
hue = ad['half']
sns.set(style="darkgrid")
ax = sns.boxplot(data=ad, x=x, y=y, hue=hue, palette="Set2", showfliers=False, showmeans = True, 
                 meanprops={"markerfacecolor":"black", 
                       "markeredgecolor":"black",
                      "markersize":"5"})
ax.set_xticks(x_pos)
ax.set_xticklabels(("Stimulus", "Silent", "No- \n feedback"))
#ax.set_title('Pong Performance By \n Condition & Time')
ax.set_ylabel('Long-Rally vs Rest (%)')
ax.set_xlabel('Group')
ax.grid(False)
ax.legend([0, 1], ["0-5", "6-20"])
L = plt.legend(loc='lower left', bbox_to_anchor=(-0.2, -0.5), title = "Minutes", borderaxespad=0.1, frameon=False)
L.get_texts()[0].set_text('0-5')
L.get_texts()[1].set_text('6-20')

y, h, col = 30, 1.5, 'k'
x00, x01 = -.2, .2
x10, x11 = .8, 1.2
x20, x21 = 1.8, 2.2
#Plot t-test between groups
plt.plot([x00, x00, x01, x01], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text(((x00 + x01)/2), y+ h, "****", ha='center', va='bottom', color=col, fontsize=8)

#Plot differences between groups time 2
plt.text(x10, y-5, "###", ha='center', va='bottom', color=col,  fontsize=8)

plt.text(x20, y-5, "#", ha='center', va='bottom', color=col, fontsize=8)



plt.text(x21, y-5, "#", ha='center', va='bottom', color=col, fontsize=8)


# Plot extra legend
#plt.text(4.4, 1.38, "#=p<0.01 \n vs Stimulus", ha='center', va='bottom', color=col)
#plt.text(4.4, 1.15, "#=p<0.05 \n vs Stimulus", ha='center', va='bottom', color=col)
#plt.text(4.4, .92, "%%=p<0.01  \n vs Silent", ha='center', va='bottom', color=col)
#plt.text(4.4, .69, "%=p<0.05  \n vs Silent", ha='center', va='bottom', color=col)

ax.set_ylim([-25, 35])
sns.set(rc={'figure.figsize':(3,3)})

#plt.savefig('/home/jovyan/work/dishpill/Analysis/Plots/feedback_lr_sig.pdf', bbox_inches='tight')

# %%
labels = data.test_day.unique()
x_pos = np.arange(len(labels))
x = Half1['test_day']
y = Half1['normlr']
hue = Half1['group']
sns.set(style="darkgrid")
ax = sns.lineplot(data=data, x=x, y=y, hue=hue, palette="Set2", err_style = "band", ci= 68)
L = plt.legend(loc='lower left', bbox_to_anchor=(-0.2, -0.6), title = "Condition", borderaxespad=0.1, frameon=False, ncol = 2)
L.get_texts()[0].set_text('Stimulus')
L.get_texts()[1].set_text('Silent')
L.get_texts()[2].set_text('No-feedback')
ax.grid(False)
ax.set_xticks(x_pos)
ax.set_xticklabels(("1", "2", "3"))
#ax.set_title('Pong Performance By \n Condition & Time')
ax.set_ylabel('Long-Rally vs Rest (%)')
ax.set_xlabel('Day of Testing')
ax.set_ylim([-5, 10])
ax.set_xlim([0, 2.4])



#plt.savefig('/home/jovyan/work/dishpill/Analysis/Plots/feedback_lr_days_sig.pdf', bbox_inches='tight')
# Out:
# (0.0, 2.4)
