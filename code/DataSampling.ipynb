# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pickle

# %%
os.listdir("../data")
# Out:
# ['in_vitro_cells_sentience_corr.pkl',
#  'in_vitro_cells_sentience_2.csv',
#  'in_vitro_cells_sentience_pilotstudies.pkl',
#  'LocalEntropies_temporal&spatial_mean_regular.pkl',
#  'LocalEntropies_temporal&spatial_mean.pkl',
#  'in_vitro_cells_sentience_HEK_control.pkl',
#  'feedback_open_loop.pkl',
#  'spikedatacorrsall1000ms.pkl',
#  'feedback_silent_feedback.pkl',
#  'LocalEntropies_temporal&spatial_rest_mean.pkl',
#  'feedback_regular_stim.pkl',
#  'in_vitro_cells_sentience_main_df.csv',
#  'spike_trains_all_regular.pkl',
#  'paddlemovement.pkl',
#  'LocalEntropies_temporal&spatial_mean_openloop.pkl',
#  'README.md',
#  'spikedatacorrsall100ms.pkl',
#  'in_vitro_cells_sentience_main_df.pkl',
#  'originaldata.pkl',
#  'spike_trains_all_openloop.pkl',
#  'original_data_rest.pkl',
#  'in_vitro_cells_sentience_corr.csv',
#  'in_vitro_cells_sentience_2.pkl',
#  'spike_trains_all_silent.pkl',
#  'in_vitro_cells_sentience_pilotstudies.csv',
# ...

# %%
with open("../data/feedback_open_loop.pkl","rb") as f:
    data = pd.read_pickle(f)
data
# Out:
#        chip_id  elapse_seconds  hit_count motor_layout       date  \
# 339782   11570          4.5475        1.0           10 2021-07-01
# 339783   11570         16.2475        1.0           10 2021-07-01
# 339784   11570         27.9475        1.0           10 2021-07-01
# 339785   11570         39.6475        1.0           10 2021-07-01
# 339786   11570         45.5275        1.0           10 2021-07-01
# ...        ...             ...        ...          ...        ...
# 492935   13168       1144.9704        0.0           10 2021-07-03
# 492936   13168       1174.0704        4.0           10 2021-07-03
# 492937   13168       1179.9704        0.0           10 2021-07-03
# 492938   13168       1185.8704        0.0           10 2021-07-03
# 492939   13168       1191.7704        0.0           10 2021-07-03
#
#         session_num                  tag electrode_config  \
# 339782          1.0   gfp_test_open_loop      gen3c-3.cfg
# ...

# %%
data.columnsumns
# Out:
# Index(['chip_id', 'elapse_seconds', 'hit_count', 'motor_layout', 'date',
#        'session_num', 'tag', 'electrode_config', 'dishserver_config',
#        'mean_firing', 'max_firing', 'var_firing', 'norm_firing', 'q95_firing',
#        'q90_firing', 'q75_firing', 'q50_firing', 'q25_firing', 'q10_firing',
#        'q05_firing', 'dct00_firing', 'dct01_firing', 'dct02_firing',
#        'dct10_firing', 'dct11_firing', 'dct12_firing', 'dct20_firing',
#        'dct21_firing', 'dct22_firing', 'project_name', 'index', 'path',
#        'error', 'group', 'elapse_minute_rounded', '20_sec', 'half', 'control',
#        'count', 'long_rally', 'ace'],
#       dtype='object')

# %%
sns.scatterplot(data, x="hit_count", hue="chip_id")
# Out:
# <Axes: xlabel='hit_count'>

# %%
data.motor_layout.unique()
# Out:
# array([10, '0'], dtype=object)
